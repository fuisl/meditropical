# %%
# !pip install -U "mineru[core]"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.4/68.4 kB 3.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.9/67.9 kB 7.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.4/40.4 kB 3.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 92.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 15.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 786.6/786.6 kB 59.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 133.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.9/51.9 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 150.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 90.6 MB/s eta 0:00:00
# ...

# %%
# !mkdir /content/raw_data/
# !mkdir /content/extracted_case_report/

# %%
# !mineru -p /content/raw_data/ -o /content/extracted_data/
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# 2025-10-29 07:33:32.018 | INFO     | mineru.backend.pipeline.pipeline_analyze:doc_analyze:125 - Batch 1/1: 261 pages/261 pages
# 2025-10-29 07:33:32.019 | INFO     | mineru.backend.pipeline.pipeline_analyze:batch_image_analyze:187 - gpu_memory: 15 GB, batch_ratio: 8
# 2025-10-29 07:33:32.020 | INFO     | mineru.backend.pipeline.model_init:__init__:208 - DocAnalysis init, this may take some times......
# Fetching 1 files:   0% 0/1 [00:00<?, ?it/s]
# models/MFD/YOLO/yolo_v8_ft.pt:   0% 0.00/350M [00:00<?, ?B/s]
# models/MFD/YOLO/yolo_v8_ft.pt:   4% 14.5M/350M [00:01<00:26, 12.8MB/s]
# models/MFD/YOLO/yolo_v8_ft.pt:  23% 81.6M/350M [00:01<00:04, 58.7MB/s]
# ...

# %%
import os

for folder in os.listdir("/content/extracted_case_report/"):
  for auto in os.listdir(f"/content/extracted_case_report/{folder}"):
    for file in os.listdir(f"/content/extracted_case_report/{folder}/{auto}"):
      if not ((file.endswith(".md")) or (file == "images")):
        os.remove(f"/content/extracted_case_report/{folder}/{auto}/{file}")

# %%
# !zip -r /content/extracted_case_report.zip /content/extracted_case_report/
# Out:
#   adding: content/extracted_data/ (stored 0%)
#   adding: content/extracted_data/19---A-40-Year-Old-Man-from-Togo-With-Subcutaneou_2022_Clinical-Cases-in-Tro/ (stored 0%)
#   adding: content/extracted_data/19---A-40-Year-Old-Man-from-Togo-With-Subcutaneou_2022_Clinical-Cases-in-Tro/auto/ (stored 0%)
#   adding: content/extracted_data/19---A-40-Year-Old-Man-from-Togo-With-Subcutaneou_2022_Clinical-Cases-in-Tro/auto/images/ (stored 0%)
#   adding: content/extracted_data/19---A-40-Year-Old-Man-from-Togo-With-Subcutaneou_2022_Clinical-Cases-in-Tro/auto/images/b801ee57fdda6538ff01e6f74775c5b44223d72273a87b8ed8e88871a8d72012.jpg (deflated 0%)
#   adding: content/extracted_data/19---A-40-Year-Old-Man-from-Togo-With-Subcutaneou_2022_Clinical-Cases-in-Tro/auto/images/3c543edc5a17a12dae4f615276fd695dd6b2224fc66cd634eda3d3926880d831.jpg (deflated 3%)
# ...

# %%
from google.colab import files
files.download('/content/extracted_case_report.zip')
