# %% [markdown]
# # Setup

# %%
# !pip install -U \
  langchain-core \
  langgraph \
  langchain-google-genai \
  google-generativeai \
  pymupdf \
  pillow \
  markdown \
  lxml \
  pandas \
  tqdm
# Out:
# Requirement already satisfied: langchain-core in /usr/local/lib/python3.12/dist-packages (1.2.7)
# Requirement already satisfied: langgraph in /usr/local/lib/python3.12/dist-packages (1.0.6)
# Collecting langgraph
#   Downloading langgraph-1.0.7-py3-none-any.whl.metadata (7.4 kB)
# Collecting langchain-google-genai
#   Downloading langchain_google_genai-4.2.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: google-generativeai in /usr/local/lib/python3.12/dist-packages (0.8.6)
# Collecting pymupdf
#   Downloading pymupdf-1.26.7-cp310-abi3-manylinux_2_28_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (11.3.0)
# Collecting pillow
#   Downloading pillow-12.1.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# Requirement already satisfied: markdown in /usr/local/lib/python3.12/dist-packages (3.10)
# Collecting markdown
#   Downloading markdown-3.10.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (6.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Collecting pandas
#   Downloading pandas-3.0.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core) (0.6.4)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain-core) (2.12.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core) (0.13.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from langgraph) (4.0.0)
# Collecting langgraph-prebuilt<1.1.0,>=1.0.7 (from langgraph)
#   Downloading langgraph_prebuilt-1.0.7-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from langgraph) (0.3.3)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from langgraph) (3.6.0)
# Collecting filetype<2.0.0,>=1.2.0 (from langchain-google-genai)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting google-genai<2.0.0,>=1.56.0 (from langchain-google-genai)
#   Downloading google_genai-1.60.0-py3-none-any.whl.metadata (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (2.29.0)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (2.188.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (2.43.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (5.29.5)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.27.0)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core->google-generativeai) (1.72.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /usr/local/lib/python3.12/dist-packages (from google-api-core->google-generativeai) (2.32.4)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.15.0->google-generativeai) (6.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.15.0->google-generativeai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.15.0->google-generativeai) (4.9.1)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (4.12.1)
# Collecting google-auth>=2.15.0 (from google-generativeai)
#   Downloading google_auth-2.48.0-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (0.28.1)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (15.0.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (1.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (1.3.1)
# Requirement already satisfied: cryptography>=38.0.3 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.15.0->google-generativeai) (43.0.3)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.0.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph) (1.12.1)
# Requirement already satisfied: orjson>=3.10.1 in /usr/local/lib/python3.12/dist-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client->google-generativeai) (0.31.1)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client->google-generativeai) (0.3.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client->google-generativeai) (4.2.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (3.11)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=38.0.3->google-auth>=2.15.0->google-generativeai) (2.0.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.76.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.71.2)
# Requirement already satisfied: pyparsing<4,>=3.0.4 in /usr/local/lib/python3.12/dist-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai) (3.3.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (0.16.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.6.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2.5.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=38.0.3->google-auth>=2.15.0->google-generativeai) (2.23)
# Downloading langgraph-1.0.7-py3-none-any.whl (157 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.4/157.4 kB 8.5 MB/s eta 0:00:00
# Downloading langchain_google_genai-4.2.0-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 5.3 MB/s eta 0:00:00
# Downloading pymupdf-1.26.7-cp310-abi3-manylinux_2_28_x86_64.whl (24.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.1/24.1 MB 52.9 MB/s eta 0:00:00
# Downloading pillow-12.1.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 82.8 MB/s eta 0:00:00
# Downloading markdown-3.10.1-py3-none-any.whl (107 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.7/107.7 kB 6.9 MB/s eta 0:00:00
# Downloading pandas-3.0.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (10.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 80.2 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading google_genai-1.60.0-py3-none-any.whl (719 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 719.4/719.4 kB 25.8 MB/s eta 0:00:00
# Downloading google_auth-2.48.0-py3-none-any.whl (236 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.5/236.5 kB 20.3 MB/s eta 0:00:00
# Downloading langgraph_prebuilt-1.0.7-py3-none-any.whl (35 kB)
# Installing collected packages: filetype, pymupdf, pillow, markdown, pandas, google-auth, google-genai, langgraph-prebuilt, langchain-google-genai, langgraph
#   Attempting uninstall: pillow
#     Found existing installation: pillow 11.3.0
#     Uninstalling pillow-11.3.0:
#       Successfully uninstalled pillow-11.3.0
#   Attempting uninstall: markdown
#     Found existing installation: Markdown 3.10
#     Uninstalling Markdown-3.10:
#       Successfully uninstalled Markdown-3.10
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 2.43.0
#     Uninstalling google-auth-2.43.0:
#       Successfully uninstalled google-auth-2.43.0
#   Attempting uninstall: google-genai
#     Found existing installation: google-genai 1.55.0
#     Uninstalling google-genai-1.55.0:
#       Successfully uninstalled google-genai-1.55.0
#   Attempting uninstall: langgraph-prebuilt
#     Found existing installation: langgraph-prebuilt 1.0.6
#     Uninstalling langgraph-prebuilt-1.0.6:
#       Successfully uninstalled langgraph-prebuilt-1.0.6
#   Attempting uninstall: langgraph
#     Found existing installation: langgraph 1.0.6
#     Uninstalling langgraph-1.0.6:
#       Successfully uninstalled langgraph-1.0.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires google-auth==2.43.0, but you have google-auth 2.48.0 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 3.0.0 which is incompatible.
# bqplot 0.12.45 requires pandas<3.0.0,>=1.0.0, but you have pandas 3.0.0 which is incompatible.
# gradio 5.50.0 requires pandas<3.0,>=1.0, but you have pandas 3.0.0 which is incompatible.
# gradio 5.50.0 requires pillow<12.0,>=8.0, but you have pillow 12.1.0 which is incompatible.
# db-dtypes 1.5.0 requires pandas<3.0.0,>=1.5.3, but you have pandas 3.0.0 which is incompatible.
# Successfully installed filetype-1.2.0 google-auth-2.48.0 google-genai-1.60.0 langchain-google-genai-4.2.0 langgraph-1.0.7 langgraph-prebuilt-1.0.7 markdown-3.10.1 pandas-3.0.0 pillow-12.1.0 pymupdf-1.26.7

# %%
# !unzip /content/drive/MyDrive/Project_Medical_LMM/Data_Processing/extracted_case_report_image_filtered.zip -d /content/
# Out:
# Archive:  /content/drive/MyDrive/Project_Medical_LMM/Data_Processing/extracted_case_report_image_filtered.zip
#    creating: /content/extracted_case_report_image_filtered/
#    creating: /content/extracted_case_report_image_filtered/case_1/
#    creating: /content/extracted_case_report_image_filtered/case_1/auto/
#   inflating: /content/extracted_case_report_image_filtered/case_1/auto/case_1.md
#    creating: /content/extracted_case_report_image_filtered/case_1/auto/images/
#   inflating: /content/extracted_case_report_image_filtered/case_1/auto/images/1026c4b35dde2d99971dcf146db97445e5335115ce9dadb6badc26a4bd9c2bf0.jpg
#   inflating: /content/extracted_case_report_image_filtered/case_1/auto/images/7274b7728e7b81d6b41e77ffc5319fe8370be1602c7074a0c6b99b9812a37ded.jpg
#    creating: /content/extracted_case_report_image_filtered/case_10/
#    creating: /content/extracted_case_report_image_filtered/case_10/auto/
#   inflating: /content/extracted_case_report_image_filtered/case_10/auto/case_10.md
#    creating: /content/extracted_case_report_image_filtered/case_10/auto/images/
#   inflating: /content/extracted_case_report_image_filtered/case_10/auto/images/1b215de74769e64112af5542b9a0ad7295b5d8b7bcc52d8fe8eaf4479d458896.jpg
#   inflating: /content/extracted_case_report_image_filtered/case_10/auto/images/3f2a0a6b30c0a4868660c0a264bd6adfa9a8b0309b1612caac9676ab326a81e3.jpg
#    creating: /content/extracted_case_report_image_filtered/case_11/
#    creating: /content/extracted_case_report_image_filtered/case_11/auto/
#   inflating: /content/extracted_case_report_image_filtered/case_11/auto/case_11.md
#    creating: /content/extracted_case_report_image_filtered/case_11/auto/images/
#   inflating: /content/extracted_case_report_image_filtered/case_11/auto/images/33118519f0e37a7c366f3c5cccc7f1c16ae349a6807bb8d85b8072340d69ffd4.jpg
#   inflating: /content/extracted_case_report_image_filtered/case_11/auto
jpg
#   inflating: /content/extracted_case_report_image_filtered/case_90/auto/images/a7a8ef8933cae8f1eca83350fd1b74ceb92a7706bbe24abb3df6cd1358979c3d.jpg
#    creating: /content/extracted_case_report_image_filtered/case_91/
#    creating: /content/extracted_case_report_image_filtered/case_91/auto/
#   inflating: /content/extracted_case_report_image_filtered/case_91/auto/case_91.md
#    creating: /content/extracted_case_report_image_filtered/case_91/auto/images/
#   inflating: /content/extracted_case_report_image_filtered/case_91/auto/images/57c0b7cbc8bfe3ce6810c32585bfe4c0eb21db1377a69781470d2ecfba6bffe2.jpg
#   inflating: /content/extracted_case_report_image_filtered/case_91/auto/images/8e9a0d7090380283cefffd03218f33a639644070aef4b4c3e04e8158da44a531.jpg
#    creating: /content/extracted_case_report_image_filtered/case_92/
#    creating: /content/extracted_case_report_image_filtered/case_92/auto/
#   inflating: /content/extracted_case_report_image_filtered/case_92/auto/case_92.md
#    creating: /content/extracted_case_report_image_filtered/case_92/auto/images/
#   inflating: /content/extracted_case_report_image_filtered/case_92/auto/images/386e85c815f94b36480135db3f169b5a6aba341d24f94c58b310376096646c79.jpg
#   inflating: /content/extracted_case_report_image_filtered/case_92/auto/images/f55740271d73974b32707919ef3bcb3125376e86b8346e849ab28021d69958e6.jpg
#    creating: /content/extracted_case_report_image_filtered/case_93/
#    creating: /content/extracted_case_report_image_filtered/case_93/auto/
#   inflating: /content/extracted_case_report_image_filtered/case_93/auto/case_93.md
#    creating: /content/extracted_case_report_image_filtered/case_93/auto/images/
#   inflating: /content/extracted_case_report_image_filtered/case_93/auto/images/13195721e1db7f755e2c073cfe07d21a6a2a0775761538a6262d2122435270ba.jpg
#   inflating: /content/extracted_case_report_image_filtered/case_93/auto/images/4a1c83e2b62a9c7b953f9b9f86462c6911bc2db77470dbfbfe6c46b738a8732d.jpg
#   inflating: /content/extracted_case_report_image_filtered/case_93/auto/images/878e94a6bef6f113b1e2c066aeec821c71389481d1240821fe1f720195d28669.jpg
#    creating: /content/extracted_case_report_image_filtered/case_94/
#    creating: /content/extracted_case_report_image_filtered/case_94/auto/
#   inflating: /content/extracted_case_report_image_filtered/case_94/auto/case_94.md
#    creating: /content/extracted_case_report_image_filtered/case_94/auto/images/
#   inflating: /content/extracted_case_report_image_filtered/case_94/auto/images/4f2ef18b5241e46c7d8f4be08c20327a2d22e75d8f386255784b672f9c76c6e9.jpg
#   inflating: /content/extracted_case_report_image_filtered/case_94/auto/images/5806c9ac5b39968185f57e4b5a81b0ead2e30cfbad71e6aac363ed459bfae4a6.jpg
#   inflating: /content/extracted_case_report_image_filtered/case_94/auto/images/a167158043f3789a3ef05e100ca5f2fedc5b57cf4f600cc0d2d9712c6d20dbd8.jpg
#   inflating: /content/extracted_case_report_image_filtered/case_94/auto/images/b5971e6f297245381ff82a1b26d76958300f606813d04fb03d1570b71504ac09.jpg

# %%
from google import genai
from google.colab import userdata
from google.genai import types
from langchain_core.messages import HumanMessage
from typing import TypedDict, Optional, List
from langchain_google_genai import ChatGoogleGenerativeAI
from langgraph.graph import StateGraph, START, END
from pathlib import Path
from IPython.display import Image, display

import os
import json
import re
import time
import pandas as pd
import pprint

os.environ["GEMINI_API_KEY"] = userdata.get("GEMINI_API_KEY_3")

# %%
MODEL_2 = "gemma-3-27b-it"
CONFIG = types.GenerateContentConfig(
  temperature=0.1
)

# %% [markdown]
# # Utils

# %%
def split_text_to_tag(text, tags):
  parsed_data = {}

  tag_pattern = '|'.join(re.escape(tag) for tag in tags)
  split_regex = fr'(<\/?(?:{tag_pattern})>)'

  split_result = re.split(split_regex, text)

  cleaned_split_result = [item.strip() for item in split_result if item.strip()]

  current_tag = None

  for item in cleaned_split_result:
    if item.startswith('<') and item.endswith('>'):
      if item.startswith('</'): # Closing tag
        current_tag = None
      else: # Opening tag
        current_tag = item[1:-1] # Extract tag name without <>
        parsed_data[current_tag] = "" # Initialize with empty string, will be populated by next item
    elif current_tag:
      # Append to existing content, as there might be multiple lines of text between tags
      if parsed_data[current_tag]:
        parsed_data[current_tag] += "\n" + item.strip()
      else:
        parsed_data[current_tag] = item.strip()
  return parsed_data

# %%
def extract_image_paths(text):
  images = []
  pattern = r'(Fig\.\s*\d+\.?\d*)\s*!\[\]\((images/[a-f0-9]+\.jpg)\)'
  matches = re.findall(pattern, text)

  if matches:
    images = [img_path for _, img_path in matches]

  return images

# %%
from google.genai import types

def load_images_as_base64(images_dir: str):
  images = []
  for img_path in Path(images_dir).glob("*.jpg"):
    with open(img_path, "rb") as f:
      images.append(
        types.Part.from_bytes(
          data=f.read(),
          mime_type="image/jpeg"
        )
      )
  return images

# %%
def load_case_report(case_path: str):
  case_path = Path(case_path)

  md_file = next(case_path.glob("*.md"))
  images_dir = case_path / "images"

  with open(md_file, "r") as f:
    text = f.read()

  images = load_images_as_base64(images_dir)
  return text, images

# %%
def select_synthesized_fields(state: dict) -> dict:
  state["flagged"] = "Yes" if state.get("flags", "GRADE_FAILED") != "NONE" else "No"

  return {
    "source": state["source"],
    "case_prompt": state.get("generated_case_prompt"),
    "final_diagnosis": state.get("generated_final_diagnosis"),
    "reasoning_points": state.get("generated_reasoning_points"),
    "reasoning_narrative": state.get("generated_reasoning_narrative"),
    "flagged": state.get("flagged"),
  }

# %% [markdown]
# # Prompt

# %%
def get_quality_grader_prompt(full_text):
  quality_grader_prompt = f"""
    You are an expert medical educator tasked with evaluating case reports for their diagnostic-reasoning value.
    You will be given full, uncleaned text that has just been extracted from PDF via OCR. You will have to understand the text because some parts are splited due to layout.
    These images are passed to you together with the case.
    The goal is to check if this case report can be use like a diagnostic teaching cases from medical textbooks.

    CASE REPORT EVALUATION RUBRIC
    >> HOW TO USE
    1. Read the entire case once without scoring.
    2. Re-read, taking notes.
    3. Inside <think>...</think>, write the reasoning that leads you to each score.
    4. Output only the five XML tags shown after the rubric—nothing else.

    +-------------------------------------------------------------+
    | 1. THOROUGHNESS OF CASE PRESENTATION (1-5 points) |
    | Look for: HPI, past history, meds, allergies, vitals,   |
    | focused exam, labs, imaging, hospital course, outcome.  |
    | 1: Seriously deficient (identifiers only; no vitals)    |
    | 2: Major gaps (HPI + vitals OR exam, not both).         |
    | 3: Adequate (present but sketchy details).              |
    | 4: Very good (complete data, clear timeline).           |
    | 5: Exemplary (serial data & course, high quality).      |
    +-------------------------------------------------------------+
    | 2. EXPLICIT DIFFERENTIAL DIAGNOSIS (Yes / No)             |
    | >=2 plausible alternatives? If yes → "Yes"; else → "No".  |
    +-------------------------------------------------------------+
    | 3. DEPENDENCE ON INTEGRATIVE CLINICAL REASONING (1-5)     |
    | Measures need to combine >=2 data points (hx, labs, etc)  |
    | 1: Trivial: lone clue gives answer.                       |
    | 2: Minimal: one dominant clue.                            |
    | 3: Moderate: must merge TWO findings.                     |
    | 4: High: THREE+ clues; requires synthesis.                |
    | 5: Outstanding: stepwise, complex reasoning.              |
    +-------------------------------------------------------------+
    | 4. TRANSPARENCY OF DIAGNOSTIC REASONING PROCESS (1-5) |
    | 1: None (no rationale).                               |
    | 2: Superficial (lists w/o "why").                     |
    | 3: Adequate (brief pivots).                           |
    | 4: Detailed (stepwise, probabilities).                |
    | 5: Model (structured, addresses pitfalls).            |
    +-------------------------------------------------------------+
    | 5. USEFULNESS OF IMAGES (1-5)                                  |
    | 1: None (no usefulness or relatedness).                        |
    | 2: Low (very limited or marginal usefulness or relevance).     |
    | 3: Average (illustration or example, limited relevance).       |
    | 4: High (high usefulness and relevance, but can be omitted).   |
    | 5: Very high (cannot be omitted without serious consequences). |
    +-------------------------------------------------------------+
    | 5. STATED FINAL DIAGNOSIS (Yes / No)                  |
    | Is diagnosis clearly named? Yes → "Yes"; else → "No". |
    +-------------------------------------------------------------+

    Additional Rules:
    1. If the given article is not actually a case report, output ”NA” for all scores.
    2. Think through whether the final diagnosis can be reasonably deduced from the case presentation when determining the
    educational value in #3.

    OUTPUT TEMPLATE (leave tags exactly as written)
    <think>
    ...your internal reasoning for each item...
    </think>

    <case_presentation_score>[1-5]</case_presentation_score>
    <differential_diagnosis_score>[Yes/No]</differential_diagnosis_score>
    <integrative_reasoning_score>[1-5]</integrative_reasoning_score>
    <transparency_score>[1-5]</transparency_score>
    <images_usefulness_score>[1-5]</images_usefulness_score>
    <final_diagnosis_score>[Yes/No]</final_diagnosis_score>

    SUPPLIED CASE REPORT
    <full_text>
    {full_text}
    </full_text>
  """

  return quality_grader_prompt

# %%
def get_extractor_prompt(full_text):
  extractor_prompt = f"""
    You are an expert clinician–educator. You are given a journal diagnostic case. Your main job is to:
    - Further extract factual details from the full text of the case. The text hasn't been cleaned or augmented.

    Besides that, your job is also to:
    - Summarize the key information of the patient for diagnosis.
    - Summarize the differential diagnosis process, including the rationale for each step and the reasons for considering or excluding specific diagnoses.
    - Summarize the final diagnosis of the patient.
    - Understand the text because some parts are splited due to the layout.
    - Check for formatting errors and typo and fix them.

    The case includes the image path after each figure. These images are passed to you together with the case.

    Ensure that your summaries are concise and accurate, based solely on the information provided in the case report.
    If the case report is incomplete or does not meet the requirements for summarization, simply output: 'I can't.'

    RULES (Read Carefully—No Exceptions)
    1. Source Fidelity – Extract facts only from the supplied case report.
    • Do NOT invent, embellish, or “smooth out” missing data.
    • Paraphrase narrative prose into concise bullets where helpful, but never add new facts.

    2. Structure the Teaching Case
    Case Presentation → Additional Infos → Question-Answer pairs → Follow-up → Disease summary and remarks

    3. Use the XML Tags Exactly as Shown
    • <think> . . . </think> – your hidden analytic notes (not visible to students).
    • <image_finding> . . . </image_finding> - your judgment about the meaning and content of the image and the helpfulness of the image.
    • <case_prompt> . . . </case_prompt> – the information given to students before they generate a differential.
    • <reasoning_points> . . . </reasoning_points> – numbered bullet reasons, each built as a full sentence followed by a direct quote.
    • <reasoning_narrative> . . . </reasoning_narrative> - the continuous narrative of the reasoning points.
    • <final_diagnosis> . . . </final_diagnosis> – single disease/entity name only, nothing more.

    4. What Goes Inside <think>
    • Key points – What makes this case non-trivial or pedagogically interesting? This should guide where the breakpoint should be.
    • Ideal breakpoint – What details of the case presentation should you include and exclude so that students have enough data to reason, but
    no spoilers?
    • Author’s analytic distinctions – How did they reach and separate the final diagnosis from look-alikes and other conditions?

    5. What Goes Inside <image_finding>
    • Description - What the image shows or displays
    • Helpfulness - How the image helps or supports the doctor in understanding the case.
    • Relevance - How relevant the image is to the patient.

    6. What Goes Inside <case_prompt>
    • Present only the facts known when recieve the patient and before a working differential was made: chief complaint, HPI, vitals, physical exam, and early investigations. No future updates or follow-up.
    • Perserve the lab and examination results.
    • Include images' names that related closely with the case, within the text right after the fact ( for example, this patient has some X-ray (Fig 100.100) ). Ensure that those images are necessary for the case prompt.
    • Present the case in the order presented in the case report (e.g., physical labs before imaging, etc.).
    • Omit any wording that directly states or hints at the final diagnosis.
    • Present this as closely as possible to the style in which the case report is written.
    • Omit repeating details.
    • Omit the answer to the question “What is the final diagnosis?”
    • Include only one question. Do not include answer.
    • Put everything into a paragraph.

    7. What Goes Inside <reasoning_points>
    • Numbered list (1., 2., 3., . . . ).
    • Discuss only about the final diagnosis, not any other findings.
    • Each entry: concise summary of reason [“direct quote from article”]. You can use ellipses (. . . ) to shorten the quote if there are irrelevant details.
    • The basis for the diagnosis and highlight the key factors supporting this conclusion. Use only the information from the case prompt
    • The steps to reach the final diagnosis from the case prompt.
    • Discuss and explain the steps to reach the final diagnosis from the case prompt.

    8. What Goes Inside <reasoning_narrative>
    • Stitching the reasoning points into a continous narrative.
    • Structure: Diagnostic steps -> Image grounding.

    9. What Goes Inside <final_diagnosis>
    • Single disease/entity name (e.g., sarcoidosis).
    • No adjectives, punctuation, or explanatory text.
    • Answer the case prompt.

    OUTPUT TEMPLATE (copy exactly, especially the tag)
    <think>
    1. [Core tension]
    2. [Best breakpoint of case report, what to include and what to exclude]
    3. [Key analytic distinctions between competing diagnoses (taken from case report)]
    </think>

    <image_finding>
    1. image_1
    Description: ...
    Helpfulness: ...
    Relevance: ...

    2. image_2
    Description: ...
    Helpfulness: ...
    Relevance: ...

    3. ...
    </image_finding>

    <case_prompt>
    [Your case presentation text, faithful to the report and stopping at the breakpoint]
    </case_prompt>

    <reasoning_points>
    1. reasoning_point_1 | Direct quote from article: "..." | Grounded in image if possible: ...

    2. reasoning_point_2 | Direct quote from article: "..." | Grounded in image if possible: ...

    3. ...
    </reasoning_points>

    <reasoning_narrative>
    ReasoningNarrative
    </reasoning_narrative>

    <final_diagnosis>
    DiseaseName
    </final_diagnosis>

    SUPPLIED CASE REPORT
    <full text>
    {full_text}
    </full text>
  """

  return extractor_prompt

# %%
def get_editor_prompt(extractor_prompt, full_text, generated_think, generated_image_finding, generated_case_prompt, generated_reasoning_points, generated_reasoning_narrative, generated_final_diagnosis):
  editor_prompt = f"""
    You are the Editor.
    Your job is to audit a draft teaching case that was produced from a published case report.
    Image are passed to you together with the case.

    You must confirm strict compliance with all instructions, detect hallucinations, and ensure pedagogic quality.

    YOUR INPUTS
      1. The original draft you must audit appears between <generated case> . . . </generated case>.
      2. The source article appears between <case report> . . . </case report>.

      Here is the original guideline the draft was produced in accordance with:
        {extractor_prompt}
      Don't take this guideline in this part as your instruction. This is just for you to review.

    CHECKLIST — FAIL ANY ITEM → RAISE A FLAG
      A. Source Fidelity
        □ Every fact in each section is traceable to the source article.
        □ No invented details or embellishments.
      B. Case Presentation Quality
        □ All facts from the case prompt are present in the source article.
        □ Contains only information known before the clinicians formed a differential.
        □ Images included must relate closely to the case prompt
        □ Does not reveal the final diagnosis (there should be room for at least some inference).
        □ Provides sufficient data (HPI, vitals, exam ± initial tests) for clinicians to formulate a reasonable differential and get the correct final diagnosis.
      C. Diagnostic Reasoning Section
        □ Each numbered entry starts with a summary of the reasoning plus a direct quote from the article.
        □ Quotes are verbatim or use ellipses (. . . ) without changing meaning.
        □ Paraphrased quotes are okay, as long as they retain the original meaning.
        □ Rationales reference only information that already appears in <case prompt> (not based on new findings, confirmatory tests, or data withheld from students).
      D. Final Diagnosis Tag
        □ Final diagnosis is reasonably deducible from the case-presentation facts. — i.e., the final diagnosis should not depend entirely on some test, imaging, or lab result not given in the case presentation.
      E. No Hallucinations Anywhere
        □ Every datum, quote, or diagnosis is found in the case report.

    HOW TO REPORT YOUR FINDINGS
      Output only the two XML blocks below.
        1. <flags> . . . </flags>
          • If an item fails, add a line FLAG: [short descriptor].
          • Use one line per failed item, drawn from this controlled vocabulary:
            CASE PROMPT HALLUCINATION, FINAL DIAGNOSIS IN CASE PROMPT,
            INSUFFICIENT INFO FOR DIAGNOSIS, DIAGNOSTIC REASONING HALLUCINATION, OTHER.
          • If no issues, write NONE.
        2. <editor comments> . . . </editor comments>
          • Briefly justify each flag (one sentence each).
          • If no flags, you may omit or leave empty.

      Example when problems exist:
        <flags>
          FLAG: SOURCE_FIDELITY
          FLAG: REASONING_EXTRA_INFO
        </flags>

        <editor_comments>
          SOURCE_FIDELITY: Mentions \family history of SLE," not present in article.
          REASONING_EXTRA_INFO: Rationale cites a biopsy result that is not included in the case_prompt.
        </editor_comments>

    OUTPUT WHEN EVERYTHING PASSES:
        <flags>
          NONE
        </flags>
        <editor_comments></editor_comments>

    INPUT BLOCKS TO REVIEW
      Here is the reference case report:
        <case_report>
          {full_text}
        </case_report>

      Here is the diagnostic case generated by the model:
        <think>
          {generated_think}
        </think>
        <image_finding>
          {generated_image_finding}
        </image_finding>
        <case_prompt>
          {generated_case_prompt}
        </case_prompt>
        <reasoning_points>
          {generated_reasoning_points}
        </reasoning_points>
        <reasoning_narrative>
          {generated_reasoning_narrative}
        </reasoning_narrative>
        <final_diagnosis>
          {generated_final_diagnosis}
        </final_diagnosis>
  """

  return editor_prompt

# %%
def get_retry_extractor_prompt(full_text, generated_think, generated_image_finding, generated_case_prompt, generated_reasoning_points, generated_reasoning_narrative, generated_final_diagnosis, flags, editor_comments):
  retry_extractor_prompt = f"""
    You are an expert clinician–educator. You are given a journal diagnostic case, your previous extraction of the case and the feedback from the editor. Your main job is to:
    - Revise your extraction given the feedback from the editor.

    Besides that, your job is also to:
    - Further extract factual details from the full text of a journal diagnostic case. The text hasn't been cleaned or augmented.
    - Summarize the key information of the patient for diagnosis.
    - Summarize the differential diagnosis process, including the rationale for each step and the reasons for considering or excluding specific diagnoses.
    - Summarize the final diagnosis of the patient.
    - Understand the text because some parts are splited due to the layout.
    - Check for formatting errors and typo and fix them.

    The case includes the image path after each figure. These images are passed to you together with the case.

    Ensure that your summaries are concise and accurate, based solely on the information provided in the case report.
    If the case report is incomplete or does not meet the requirements for summarization, simply output: 'I can't.'

    RULES (Read Carefully—No Exceptions)
    1. Source Fidelity – Extract facts only from the supplied case report.
    • Do NOT invent, embellish, or “smooth out” missing data.
    • Paraphrase narrative prose into concise bullets where helpful, but never add new facts.

    2. Structure the Teaching Case
    Case Presentation → Additional Infos → Question-Answer pairs → Follow-up → Disease summary and remarks

    3. Use the XML Tags Exactly as Shown
    • <think> . . . </think> – your hidden analytic notes (not visible to students).
    • <image_finding> . . . </image_finding> - your judgment about the meaning and content of the image and the helpfulness of the image.
    • <case_prompt> . . . </case_prompt> – the information given to students before they generate a differential.
    • <reasoning_points> . . . </reasoning_points> – numbered bullet reasons, each built as a full sentence followed by a direct quote.
    • <reasoning_narrative> . . . </reasoning_narrative> - the continuous narrative of the reasoning points.
    • <final_diagnosis> . . . </final_diagnosis> – single disease/entity name only, nothing more.

    4. What Goes Inside <think>
    * Key points – What makes this case non-trivial or pedagogically interesting? This should guide where the breakpoint should be.
    * Ideal breakpoint – What details of the case presentation should you include and exclude so that students have enough data to reason, but
    no spoilers?
    * Author’s analytic distinctions – How did they reach and separate the final diagnosis from look-alikes and other conditions?

    5. What Goes Inside <image_finding>
    • Description - What the image shows or displays
    • Helpfulness - How the image helps or supports the doctor in understanding the case.
    • Relevance - How relevant the image is to the patient.

    6. What Goes Inside <case_prompt>
    • Present only the facts known when recieve the patient and before a working differential was made: chief complaint, HPI, vitals, physical exam, and early investigations. No future updates or follow-up.
    • Perserve the lab and examination results.
    • Include images' names that related closely with the case, within the text right after the fact ( for example, this patient has some X-ray (Fig 100.100) ). Ensure that those images are necessary for the case prompt.
    • Present the case in the order presented in the case report (e.g., physical labs before imaging, etc.).
    • Omit any wording that directly states or hints at the final diagnosis.
    • Present this as closely as possible to the style in which the case report is written.
    • Omit repeating details.
    • Omit the answer to the question “What is the final diagnosis?”
    • Include only one question. Do not include answer.
    • Put everything into a paragraph.

    7. What Goes Inside <reasoning_points>
    • Numbered list (1., 2., 3., . . . ).
    • Discuss only about the final diagnosis, not any other findings.
    • Each entry: concise summary of reason [“direct quote from article”]. You can use ellipses (. . . ) to shorten the quote if there are irrelevant details.
    • The basis for the diagnosis and highlight the key factors supporting this conclusion. Use only the information from the case prompt
    • The steps to reach the final diagnosis from the case prompt.
    • Discuss and explain the steps to reach the final diagnosis from the case prompt.

    8. What Goes Inside <reasoning_narrative>
    • Stitching the reasoning points into a continous narrative.
    • Structure: Diagnostic steps -> Image grounding.

    9. What Goes Inside <final_diagnosis>
    • Single disease/entity name (e.g., sarcoidosis).
    • No adjectives, punctuation, or explanatory text.
    • Answer the case prompt.

    OUTPUT TEMPLATE (copy exactly, especially the tag)
    <think>
    1. [Core tension]
    2. [Best breakpoint of case report, what to include and what to exclude]
    3. [Key analytic distinctions between competing diagnoses (taken from case report)]
    </think>

    <image_finding>
    1. image_1
    Description: ...
    Helpfulness: ...
    Relevance: ...

    2. image_2
    Description: ...
    Helpfulness: ...
    Relevance: ...

    3. ...
    </image_finding>

    <case_prompt>
    [Your case presentation text, faithful to the report and stopping at the breakpoint]
    </case_prompt>

    <reasoning_points>
    1. reasoning_point_1 | Direct quote from article: "..." | Grounded in image if possible: ...

    2. reasoning_point_2 | Direct quote from article: "..." | Grounded in image if possible: ...

    3. ...
    </reasoning_points>

    <reasoning_narrative>
    ReasoningNarrative
    </reasoning_narrative>

    <final_diagnosis>
    DiseaseName
    </final_diagnosis>


    SUPPLIED CASE REPORT
    <full text>
    {full_text}
    </full text>

    PREVIOUS EXTRACTION
    <think>
      {generated_think}
    </think>
    <image_finding>
      {generated_image_finding}
    </image_finding>
    <case_prompt>
      {generated_case_prompt}
    </case_prompt>
    <reasoning_points>
      {generated_reasoning_points}
    </reasoning_points>
    <reasoning_narrative>
      {generated_reasoning_narrative}
    </reasoning_narrative>
    <final_diagnosis>
      {generated_final_diagnosis}
    </final_diagnosis>

    EDITOR COMMENTS
    <flags>
      {flags}
    </flags>
    <editor_comments>
      {editor_comments}
    </editor_comments>
  """

  return retry_extractor_prompt

# %% [markdown]
# # State and Graph

# %%
class CaseState(TypedDict):
  source: str
  case_path: str

  full_text: str
  images: list

  # grading
  grading: Optional[dict]
  passed_grading: bool

  # monitor
  retry: bool
  loop_count: int

  # extraction
  generated_think: Optional[str]
  generated_image_finding: Optional[str]
  generated_case_prompt: Optional[str]
  generated_reasoning_points: Optional[str]
  generated_reasoning_narrative: Optional[str]
  generated_final_diagnosis: Optional[str]

  flags: Optional[str]
  editor_comments: Optional[str]

# %%
multimodal_llm = ChatGoogleGenerativeAI(
  model=MODEL_2,
  google_api_key=os.environ["GEMINI_API_KEY"],
  temperature=0.1,
)

agent = genai.Client(api_key=os.environ["GEMINI_API_KEY"])

# %%
def load_case(state: CaseState):
    full_text, images = load_case_report(state["case_path"])

    time.sleep(5)

    return {
        "full_text": full_text,
        "images": images,
        "retry": False,
        "loop_count": 0,
    }

# %%
def grade_case(state: CaseState):
    prompt = get_quality_grader_prompt(state["full_text"])

    contents = [prompt, *state["images"]]

    response = agent.models.generate_content(
        model=MODEL_2,
        contents=contents,
        config=CONFIG,
    )

    if response.text in (None, "I can't."):
        return {"passed_grading": False}

    grading = split_text_to_tag(
        response.text,
        [
            "think",
            "case_presentation_score",
            "differential_diagnosis_score",
            "integrative_reasoning_score",
            "transparency_score",
            "images_usefulness_score",
            "final_diagnosis_score",
        ],
    )

    passed = (
        int(grading["case_presentation_score"]) >= 3
        and int(grading["integrative_reasoning_score"]) >= 3
        and int(grading["transparency_score"]) >= 3
        and int(grading["images_usefulness_score"]) >= 3
        and grading["differential_diagnosis_score"] == "Yes"
        and grading["final_diagnosis_score"] == "Yes"
    )

    grading["source"] = state["source"]

    time.sleep(5)

    return {
        "grading": grading,
        "passed_grading": passed,
    }

# %%
def grade_route(state: CaseState):
  if state["passed_grading"]:
    time.sleep(5)
    return "extract_case"

  time.sleep(5)
  return END

# %%
def extract_case(state: CaseState):
    full_text = state["full_text"]

    if state["retry"]:
        prompt = get_retry_extractor_prompt(
            full_text,
            state["generated_think"],
            state["generated_image_finding"],
            state["generated_case_prompt"],
            state["generated_reasoning_points"],
            state["generated_reasoning_narrative"],
            state["generated_final_diagnosis"],
            state["flags"],
            state["editor_comments"],
        )
    else:
        prompt = get_extractor_prompt(full_text)

    contents = [prompt, *state["images"]]

    response = agent.models.generate_content(
        model=MODEL_2,
        contents=contents,
        config=CONFIG,
    )

    if response.text in (None, "I can't."):
      time.sleep(5)
      return {
          "flags": "NONE",
          "generated_think": state.get("generated_think"),
          "generated_image_finding": state.get("generated_image_finding"),
          "generated_case_prompt": state.get("generated_case_prompt"),
          "generated_reasoning_points": state.get("generated_reasoning_points"),
          "generated_reasoning_narrative": state.get("generated_reasoning_narrative"),
          "generated_final_diagnosis": state.get("generated_final_diagnosis"),
      }

    parsed = split_text_to_tag(
        response.text,
        [
            "think",
            "image_finding",
            "case_prompt",
            "reasoning_points",
            "reasoning_narrative",
            "final_diagnosis",
        ],
    )

    time.sleep(5)
    return {
        "generated_think": parsed["think"],
        "generated_image_finding": parsed["image_finding"],
        "generated_case_prompt": parsed["case_prompt"],
        "generated_reasoning_points": parsed["reasoning_points"],
        "generated_reasoning_narrative": parsed["reasoning_narrative"],
        "generated_final_diagnosis": parsed["final_diagnosis"],
    }

# %%
def review_case(state: CaseState):
    editor_prompt = get_editor_prompt(
        "",
        state["full_text"],
        state["generated_think"],
        state["generated_image_finding"],
        state["generated_case_prompt"],
        state["generated_reasoning_points"],
        state["generated_reasoning_narrative"],
        state["generated_final_diagnosis"],
    )

    contents = [editor_prompt, *state["images"]]

    response = agent.models.generate_content(
        model=MODEL_2,
        contents=contents,
        config=CONFIG,
    )

    parsed = split_text_to_tag(response.text, ["flags", "editor_comments"])

    time.sleep(5)
    return {
        "flags": parsed["flags"],
        "editor_comments": parsed["editor_comments"],
        "retry": parsed["flags"] != "NONE",
        "loop_count": state["loop_count"] + 1,
    }

# %%
def review_route(state: CaseState):
    if state["flags"] == "NONE":
        return END
    return "extract_case"

# %%
graph = StateGraph(CaseState)

graph.add_node("load_case", load_case)
graph.add_node("grade_case", grade_case)
graph.add_node("extract_case", extract_case)
graph.add_node("review_case", review_case)

graph.set_entry_point("load_case")

graph.add_edge("load_case", "grade_case")

graph.add_conditional_edges(
    "grade_case",
    grade_route,
    {
        "extract_case": "extract_case",
        END: END,
    },
)

graph.add_edge("extract_case", "review_case")

graph.add_conditional_edges(
    "review_case",
    review_route,
    {
        "extract_case": "extract_case",
        END: END,
    },
)

app = graph.compile()
display(Image(app.get_graph(xray=1).draw_mermaid_png()))

# %% [markdown]
# # Debug run on 1 case

# %%
import os

result = app.invoke({
    "source": "case_4",
    "case_path": f"/content/extracted_case_report_image_filtered/case_4/auto",
})

record = select_synthesized_fields(result)

out_path = f"/content/outputs/{result['source']}.json"

os.makedirs(os.path.dirname(out_path), exist_ok=True)

with open(out_path, "w") as f:
    json.dump(record, f, indent=2)

# %%
pprint.pprint(result['generated_case_prompt'])
# Out:
# ('A 4-year-old girl from rural eastern Uganda is brought to the Accident and '
#  'Emergency (A&E) Department in a coma. Her father reports she was well until '
#  'yesterday when she developed a headache followed by shaking chills. The '
#  'family suspected malaria and planned to seek care in the morning, but she '
#  'developed a 10-minute seizure at 5 a.m. and has remained unconscious since. '
#  'She has no history of head trauma.\n'
#  '\n'
#  'On examination, her temperature is 38.7°C (101.7°F), pulse is 150 bpm, '
#  'respiratory rate is 36 breaths per minute, and blood pressure is 98/40 mmHg. '
#  'She has no neck stiffness or jaundice, and capillary refill is normal. There '
#  'is nasal flaring with respirations. Her Blantyre Coma Scale is 1/5. Pupils '
#  'are 2 mm and reactive, and extraocular movements are normal. She has no '
#  'papilloedema. With stimulation, she exhibits decerebrate posturing that '
#  'resolves spontaneously. Cardiac examination reveals a gallop rhythm. Her '
#  'liver is palpable 2 cm below the right costal margin, and her spleen is 4 cm '
#  'below the left costal margin. A rapid glucose test is normal.\n'
#  '\n'
#  'Laboratory results are as follows:\n'
#  'Haematocrit: 17.6% (reference ≥30%)\n'
#  'Platelet count: 28 x10^9/L (reference 150-450 x10^9/L)\n'
#  'Malaria RDT: Positive (reference Negative)\n'
#  '\n'
#  '<image_1>Fig. 4.1</image_1>\n'
#  '<image_3>Table 4.1</image_3>\n'
#  '\n'
#  'What is the differential diagnosis?')

# %%
pprint.pprint(result['generated_reasoning_points'])
# Out:
# ('1. The patient presents with coma, fever, and a positive malaria RDT, '
#  'raising suspicion for cerebral malaria. “The World Health Organization (WHO) '
#  'defines cerebral malaria as an ‘otherwise unexplained coma in a patient with '
#  'malaria parasitaemia’.”\n'
#  '2. However, the case emphasizes that a positive RDT alone is not diagnostic '
#  'in areas with high malaria transmission. “A positive malaria rapid '
#  'diagnostic test (RDT) does not rule out an underlying non-malarial aetiology '
#  'of acute illness.”\n'
#  '3. The presence of anemia and thrombocytopenia further supports the '
#  'possibility of malaria, but these findings are also seen in other '
#  'conditions. “Early laboratory testing reveals anaemia and '
#  'thrombocytopenia.”\n'
#  '4. The absence of neck stiffness does not exclude meningitis, given the '
#  'patient’s deep coma. “Although there is no neck stiffness, she is deeply '
#  'comatose, making this clinical finding less reliable; the absence of neck '
#  'stiffness should not lower the clinician’s suspicion of meningitis.”\n'
#  '5. The finding of hepatosplenomegaly is consistent with malaria, but can '
#  'also be seen in other infections and hematologic disorders. “She has no neck '
#  'stiffness or jaundice. Capillary refill is normal. There is nasal flaring '
#  'with respirations. Blantyre Coma Scale is 1/5. Pupils are $2 \\mathrm { m m '
#  '}$ and reactive, and extraocular movements are normal by oculocephalic '
#  'manoeuvres. She has no papilloedema on direct ophthalmoscopy. With '
#  'stimulation there is decerebrate posturing that resolves spontaneously. On '
#  'cardiac examination she has a gallop rhythm. Her liver is palpable $2 '
#  '\\mathrm { c m }$ below the right costal margin and her spleen is $4 '
#  '\\mathrm { c m }$ below the left costal margin.”')

# %%
pprint.pprint(result['generated_reasoning_narrative'])
# Out:
# ('The diagnostic process begins with considering the most likely causes of '
#  'coma in a 4-year-old from rural Uganda, given the clinical presentation of '
#  'fever, altered mental status, and a positive malaria RDT. Cerebral malaria '
#  'is immediately high on the differential, as defined by the WHO criteria. '
#  'However, the case emphasizes the importance of not solely relying on the RDT '
#  'result, particularly in a region with high malaria transmission rates. Other '
#  'potential causes, such as bacterial meningitis, viral encephalitis, and '
#  'metabolic abnormalities, must also be considered. The presence of anemia and '
#  'thrombocytopenia supports the possibility of malaria, but these findings are '
#  'not specific. The absence of neck stiffness does not rule out meningitis due '
#  'to the patient’s deep coma. The case highlights the need for further '
#  'investigations to differentiate between malarial and non-malarial etiologies '
#  'of coma. The image of malarial retinopathy (Fig. 4.1) is crucial in this '
#  'differentiation, as its presence strongly suggests a malarial cause.')

# %%
pprint.pprint(result['generated_final_diagnosis'])
# Out:
# 'Cerebral malaria'

# %%
display(result)
# Out:
# {'source': 'case_1',
#  'case_path': '/content/extracted_case_report_image_filtered/case_1/auto',
#  'full_text': '# 1\n\n# A 20-Year-Old Woman from Sudan With Fever, Haemorrhage and Shock\n\nDANIEL G. BAUSCH\n\n# Clinical Presentation\n\n# History\n\nA 20-year-old housewife presents to a hospital in northern Uganda with a 2-day history of fever, severe asthenia, chest and abdominal pain, nausea, vomiting, diarrhoea and slight non-productive cough. The patient is a Sudanese refugee living in a camp in the region. She denies any contact with sick people.\n\n# Clinical Findings\n\nThe patient is prostrate and semiconscious on admission. Vital signs: temperature $3 9 . 6 ^ { \\circ } \\mathrm { C } ,$ $( 1 0 3 . 3 ^ { \\circ } \\mathrm { F } )$ blood pressure $9 0 / 6 0 \\mathrm { m m H g }$ , pulse $9 0 \\mathrm { b p m }$ , and respiratory rate 24 cycles per minute. Physical examination revealed abdominal tenderness, especially in the right upper quadrant, hepatosplenomegaly and bleeding from the gums. The lungs were clear. No rash or lymphadenopathy was noted.\n\n# Questions\n\n1. Is the patient’s history and clinical presentation consistent with a haemorrhagic fever (HF) syndrome? 2. What degree of nursing precautions need to be implemented?\n\n# Discussion\n\nThis patient was seen during an outbreak of Ebola virus disease in northern Uganda, so the diagnosis was strongly suspected. She was admitted to the isolation ward that had been established as part of the international outbreak response. No clinical laboratory data were available because, for biosafety reasons, such testing was suspended. Although it is a reasonable precaution, the suspension of routine testing often causes difficulty in ruling out the many other febrile syndromes in the differential diagnosis and increases mortality from other non-Ebola disease. Fortunately, many clinical laboratory tests can now be safely performed with point-of-care instruments, often brought into a specialized laboratory in the isolation ward, as long as the laboratory personnel are properly trained and equipped.\n\n# Answer to Question 1\n\n# Is the Patient’s History and Clinical Presentation Consistent with an HF Syndrome?\n\nThe clinical presentation is indeed one of classic viral HF. However, most times the diagnosis is not so easy. Although some patients, such as this one, do progress to the classic syndrome with haemorrhage, multiple organ dysfunction syndrome and shock, haemorrhage is not invariably seen (and may even be noted in only a minority of cases with some virus species), and severe and fatal disease may still occur in its absence. The clinical presentation of viral HF is often very non-specific. Furthermore, haemorrhage may be seen in numerous other syndromes, such as complicated malaria, typhoid fever, bacterial gastroenteritis and leptospirosis, which are the primary differential diagnoses, depending on the region.\n\n# Answer to Question 2\n\n# What Degree of Nursing Precautions Needs to be Implemented?\n\nThe spread of Ebola virus between humans is through direct contact with blood or bodily fluids. Secondary attack rates are generally $1 5 \\%$ to $2 0 \\%$ during outbreaks in Africa, and much lower if proper universal precautions are maintained. Specialized viral HF precautions and personal protective equipment are warranted when there is a confirmed case or high index of suspicion, such as in this case.\n\n# The Case Continued. . .\n\nIntravenous fluids, broad-spectrum antibiotics and analgesics were begun on admission. Nevertheless, the patient’s condition rapidly worsened, with subconjunctival haemorrhage, copious bleeding from the mouth, nose and rectum (Fig. 1.1 ![](images/7274b7728e7b81d6b41e77ffc5319fe8370be1602c7074a0c6b99b9812a37ded.jpg) and Fig. 1.2 ![](images/1026c4b35dde2d99971dcf146db97445e5335115ce9dadb6badc26a4bd9c2bf0.jpg)), dyspnoea and hypothermic shock (temperature $3 6 . 0 ^ { \\circ } \\mathrm { C }$ , blood pressure $=$ unreadable, pulse $1 5 0 \\mathrm { b p m }$ , respiratory rate 36 cycles per minute). She became comatose and died app ...
#  'images': [Part(
#     inline_data=Blob(
#       data=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x08\x06\x06\x07\x06\x05\x08\x07\x07\x07\t\t\x08\n\x0c\x14\r\x0c\x0b\x0b\x0c\x19\x12\x13\x0f\x14\x1d\x1a\x1f\x1e\x1d\x1a\x1c\x1c $.\' ",#\x1c\x1c(7),01444\x1f\'9=82<.342\xff\xdb\x00C\x01\t\t\t...',
#       mime_type='image/jpeg'
#     )
#   ),
#   Part(
#     inline_data=Blob(
#       data=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x08\x06\x06\x07\x06\x05\x08\x07\x07\x07\t\t\x08\n\x0c\x14\r\x0c\x0b\x0b\x0c\x19\x12\x13\x0f\x14\x1d\x1a\x1f\x1e\x1d\x1a\x1c\x1c $.\' ",#\x1c\x1c(7),01444\x1f\'9=82<.342\xff\xdb\x00C\x01\t\t\t...',
#       mime_type='image/jpeg'
#     )
#   )],
#  'grading': {'think': "The case report presents a 20-year-old Sudanese refugee with a rapid onset of fever, hemorrhage, and shock. The history is concise but relevant, and vital signs are provided. The physical exam findings are described, though somewhat briefly. Lab data is initially unavailable due to biosafety concerns, but later confirmed the diagnosis. The hospital course is described, leading to a fatal outcome. The case is well-structured, though lacks serial lab values.\n\nA clear differential diagnosis isn't explicitly listed, but the text discusses other potential causes of similar symptoms (malaria, typhoid, etc.). The case strongly suggests a hemorrhagic fever syndrome, and the context of an Ebola outbreak narrows the possibilities.\n\nThe reasoning relies heavily on the epidemiological context (Ebola outbreak) and the progression of symptoms. The initial suspicion of Ebola, followed by the rapid deterioration and hemorrhagic manifestations, points towards the diagnosis. The final confirmation with lab tests solidifies the reasoning. It requires integrating the history, clinical findings, and epidemiological context.\n\nThe transparency of the reasoning is adequate. The text explains why Ebola was suspected and how the clinical picture evolved. However, it doesn't delve into probabilities or a detailed step-by-step analysis of the differential.\n\nThe images are extremely useful. They vividly demonstrate the severe hemorrhagic manifestations of the disease, which are crucial for understanding the clinical presentation of Ebola. Without the images, the severity of the case would be significantly underestimated.\n\nThe final diagnosis (Ebola virus disease) is clearly stated and confirmed by laboratory testing.",
#   'case_presentation_score': '4',
#   'differential_diagnosis_score': 'Yes',
#   'integrative_reasoning_score': '4',
#   'transparency_score': '3',
#   'images_usefulness_score': '5',
#   'final_diagnosis_score': 'Yes',
#   'source': 'case_1'},
#  'passed_grading': True,
#  'retry': False,
#  'loop_count': 1,
#  'generated_think': '1. Core tension: This case highlights the challenge of diagnosing Ebola virus disease in a setting with limited laboratory resources and the importance of considering it in the differential diagnosis of febrile illnesses in endemic areas, even when initial presentation is non-specific.\n2. Best breakpoint: The ideal breakpoint is after the "Discussion" section answering the initial questions (1 & 2). This provides students with the initial clinical presentation, vital signs, physical exam findings, and the context of a potential Ebola outbreak, without revealing the final diagnosis.\n3. Key analytic distinctions: The case emphasizes the non-specific nature of early Ebola symptoms, overlapping with other tropical diseases like malaria and typhoid fever. The rapid progression to hemorrhage and shock, coupled with the epidemiological context, are crucial for narrowing the differential. The case also highlights the importance of considering Ebola even when routine lab tests are unavailable.',
#  'generated_image_finding': "1. image_1\nDescription: The image shows a patient lying in a hospital bed with significant bleeding from the mouth and nose. There is blood on the bedding and the patient appears severely ill.\nHelpfulness: The image vividly demonstrates the hemorrhagic manifestations of the disease, supporting the clinical description of severe bleeding.\nRelevance: Highly relevant as it illustrates a key clinical feature of the patient's condition and the severity of the illness.\n\n2. image_2\nDescription: A close-up image of the patient's face, showing profuse bleeding from the mouth and nose. The patient's eyes are partially open and appear sunken.\nHelpfulness: This image further emphasizes the severity of the hemorrhage and the patient's deteriorating condition.\nRelevance: Highly relevant, providing a detailed view of the hemorrhagic symptoms.",
#  'generated_case_prompt': 'A 20-year-old housewife presents to a hospital in northern Uganda with a 2-day history of fever, severe asthenia, chest and abdominal pain, nausea, vomiting, diarrhoea and slight non-productive cough. The patient is a Sudanese refugee living in a camp in the region. She denies any contact with sick people.\n\nThe patient is prostrate and semiconscious on admission. Vital signs: temperature $39.6 ^ { \\circ } \\mathrm { C }$, blood pressure $90 / 60 \\mathrm { m m H g}$, pulse $90 \\mathrm { b p m}$, and respiratory rate 24 cycles per minute. Physical examination revealed abdominal tenderness, especially in the right upper quadrant, hepatosplenomegaly and bleeding from the gums. The lungs were clear. No rash or lymphadenopathy was noted.\n\nFig. 1.1 and Fig. 1.2 show the patient with bleeding from the mouth and nose.\n\nWhat is the most likely diagnosis?',
#  'generated_reasoning_points': '1. The patient’s presentation with fever, asthenia, abdominal pain, and bleeding, coupled with the epidemiological context of an Ebola outbreak in northern Uganda, strongly suggests Ebola virus disease. “This patient was seen during an outbreak of Ebola virus disease in northern Uganda, so the diagnosis was strongly suspected.”\n2. The rapid deterioration of the patient’s condition, including the development of subconjunctival hemorrhage, copious bleeding from multiple sites, dyspnea, and hypothermic shock, is consistent with the progression of Ebola virus disease. “Nevertheless, the patient’s condition rapidly worsened, with subconjunctival haemorrhage, copious bleeding from the mouth, nose and rectum…and hypothermic shock.”\n3. The confirmation of Ebola virus through ELISA antigen and PCR testing further supports the diagnosis. “Laboratory testing at a specialized laboratory…showed positive ELISA antigen and PCR tests for Ebola virus…”',
#  'generated_reasoning_narrative': 'The diagnostic process began with recognizing the patient’s non-specific symptoms – fever, asthenia, and gastrointestinal distress – in the context of an ongoing Ebola outbreak. The physical exam findings of abdominal tenderness, hepatosplenomegaly, and gum bleeding raised suspicion for a hemorrhagic fever syndrome. The rapid clinical deterioration, evidenced by the development of subconjunctival and mucosal hemorrhages (as seen in Fig. 1.1 and Fig. 1.2), and progression to shock, further strengthened the suspicion for Ebola. Finally, the laboratory confirmation through positive ELISA and PCR tests solidified the diagnosis.',
#  'generated_final_diagnosis': 'Ebola virus disease',
#  'flags': 'NONE',
#  'editor_comments': '',
#  'flagged': 'No'}

# %% [markdown]
# # Run on all cases

# %%
from pathlib import Path
import json

CASES_ROOT = Path("/content/extracted_case_report_image_filtered/")
OUTPUT_DIR = Path("/content/outputs/")
OUTPUT_DIR.mkdir(exist_ok=True)

for case_dir in CASES_ROOT.iterdir():
    if not case_dir.is_dir():
        continue

    source = case_dir.name
    case_path = case_dir / "auto"

    out_file = OUTPUT_DIR / f"{source}.json"
    if out_file.exists():
        print(f"⏭ {source} already exists, skipping")
        continue

    print(f"▶ Processing {source}")

    try:
        result = app.invoke({
            "source": source,
            "case_path": str(case_path),
        })

        record = select_synthesized_fields(result)

        with open(OUTPUT_DIR / f"{source}.json", "w") as f:
            json.dump(record, f, indent=2)

    except Exception as e:
        print(f"❌ Failed {source}: {e}")

    print(f"✅ Done {source}")
    print()
    time.sleep(15)
# Out:
# ⏭ case_80 already exists, skipping
# ⏭ case_17 already exists, skipping
# ⏭ case_62 already exists, skipping
# ⏭ case_47 already exists, skipping
# ▶ Processing case_3
# ✅ Done case_3
#
# ⏭ case_88 already exists, skipping
# ⏭ case_58 already exists, skipping
# ⏭ case_69 already exists, skipping
# ⏭ case_51 already exists, skipping
# ⏭ case_86 already exists, skipping
# ⏭ case_8 already exists, skipping
# ⏭ case_24 already exists, skipping
# ⏭ case_36 already exists, skipping
# ⏭ case_33 already exists, skipping
# ⏭ case_46 already exists, skipping
# ⏭ case_34 already exists, skipping
# ⏭ case_20 already exists, skipping
# ⏭ case_56 already exists, skipping
# ⏭ case_12 already exists, skipping
# ⏭ case_76 already exists, skipping
# ⏭ case_75 already exists, skipping
# ⏭ case_28 already exists, skipping
# ⏭ case_66 already exists, skipping
# ⏭ case_11 already exists, skipping
# ⏭ case_59 already exists, skipping
# ⏭ case_71 already exists, skipping
# ⏭ case_7 already exists, skipping
# ⏭ case_85 already exists, skipping
# ⏭ case_81 already exists, skipping
# ⏭ case_84 already exists, skipping
# ⏭ case_19 already exists, skipping
# ⏭ case_23 already exists, skipping
# ⏭ case_45 already exists, skipping
# ⏭ case_52 already exists, skipping
# ⏭ case_77 already exists, skipping
# ⏭ case_57 already exists, skipping
# ⏭ case_14 already exists, skipping
# ⏭ case_74 already exists, skipping
# ⏭ case_32 already exists, skipping
# ⏭ case_89 already exists, skipping
# ⏭ case_67 already exists, skipping
# ⏭ case_37 already exists, skipping
# ⏭ case_15 already exists, skipping
# ⏭ case_72 already exists, skipping
# ⏭ case_1 already exists, skipping
# ⏭ case_31 already exists, skipping
# ⏭ case_30 already exists, skipping
# ⏭ case_39 already exists, skipping
# ⏭ case_5 already exists, skipping
# ⏭ case_29 already exists, skipping
# ⏭ case_64 already exists, skipping
# ⏭ case_61 already exists, skipping
# ⏭ case_9 already exists, skipping
# ⏭ case_91 already exists, skipping
# ⏭ case_65 already exists, skipping
# ⏭ case_79 already exists, skipping
# ⏭ case_4 already exists, skipping
# ⏭ case_38 already exists, skipping
# ⏭ case_6 already exists, skipping
# ⏭ case_54 already exists, skipping
# ⏭ case_49 already exists, skipping
# ⏭ case_2 already exists, skipping
# ⏭ case_44 already exists, skipping
# ⏭ case_22 already exists, skipping
# ⏭ case_92 already exists, skipping
# ▶ Processing case_43
# ✅ Done case_43
#
# ⏭ case_73 already exists, skipping
# ⏭ case_55 already exists, skipping
# ⏭ case_10 already exists, skipping
# ⏭ case_50 already exists, skipping
# ⏭ case_42 already exists, skipping
# ⏭ case_83 already exists, skipping
# ⏭ case_13 already exists, skipping
# ⏭ case_40 already exists, skipping
# ⏭ case_94 already exists, skipping
# ⏭ case_60 already exists, skipping
# ⏭ case_21 already exists, skipping
# ⏭ case_35 already exists, skipping
# ⏭ case_87 already exists, skipping
# ⏭ case_90 already exists, skipping
# ⏭ case_53 already exists, skipping
# ⏭ case_82 already exists, skipping
# ⏭ case_26 already exists, skipping
# ⏭ case_70 already exists, skipping
# ⏭ case_63 already exists, skipping
# ⏭ case_78 already exists, skipping
# ⏭ case_27 already exists, skipping
# ⏭ case_41 already exists, skipping
# ⏭ case_25 already exists, skipping
# ⏭ case_68 already exists, skipping
# ⏭ case_16 already exists, skipping
# ⏭ case_93 already exists, skipping
# ⏭ case_48 already exists, skipping

# %%
# !zip -r /content/outputs.zip /content/outputs
# Out:
#   adding: content/outputs/ (stored 0%)
#   adding: content/outputs/case_28.json (deflated 55%)
#   adding: content/outputs/case_26.json (deflated 34%)
#   adding: content/outputs/case_5.json (deflated 56%)
#   adding: content/outputs/case_78.json (deflated 60%)
#   adding: content/outputs/case_8.json (deflated 59%)
#   adding: content/outputs/case_79.json (deflated 58%)
#   adding: content/outputs/case_80.json (deflated 54%)
#   adding: content/outputs/case_36.json (deflated 34%)
#   adding: content/outputs/case_92.json (deflated 56%)
#   adding: content/outputs/case_61.json (deflated 56%)
#   adding: content/outputs/case_47.json (deflated 54%)
#   adding: content/outputs/case_20.json (deflated 53%)
#   adding: content/outputs/case_74.json (deflated 52%)
#   adding: content/outputs/case_60.json (deflated 54%)
#   adding: content/outputs/case_11.json (deflated 57%)
#   adding: content/outputs/case_90.json (deflated 55%)
#   adding: content/outputs/case_71.json (deflated 52%)
#   adding: content/outputs/case_6.json (deflated 56%)
#   adding: content/outputs/case_54.json (deflated 55%)
#   adding: content/outputs/case_42.json (deflated 57%)
#   adding: content/outputs/case_52.json (deflated 55%)
#   adding: content/outputs/case_39.json (deflated 54%)
#   adding: content/outputs/case_40.json (deflated 34%)
#   adding: content/outputs/case_84.json (deflated 34%)
#   adding: content/outputs/case_45.json (deflated 34%)
#   adding: content/outputs/case_86.json (deflated 34%)
#   adding: content/outputs/case_14.json (deflated 59%)
#   adding: content/outputs/case_67.json (deflated 57%)
#   adding: content/outputs/case_66.json (deflated 57%)
#   adding: content/outputs/case_85.json (deflated 55%)
#   adding: content/outputs/case_30.json (deflated 60%)
#   adding: content/outputs/case_82.json (deflated 57%)
#   adding: content/outputs/case_73.json (deflated 53%)
#   adding: content/outputs/case_38.json (deflated 58%)
#   adding: content/outputs/case_87.json (deflated 54%)
#   adding: content/outputs/case_9.json (deflated 54%)
#   adding: content/outputs/case_12.json (deflated 34%)
#   adding: content/outputs/case_13.json (deflated 51%)
#   adding: content/outputs/case_2.json (deflated 56%)
#   adding: content/outputs/case_27.json (deflated 56%)
#   adding: content/outputs/case_34.json (deflated 34%)
#   adding: content/outputs/case_4.json (deflated 54%)
#   adding: content/outputs/case_25.json (deflated 55%)
#   adding: content/outputs/case_15.json (deflated 56%)
#   adding: content/outputs/case_22.json (deflated 54%)
#   adding: content/outputs/case_21.json (deflated 56%)
#   adding: content/outputs/case_48.json (deflated 56%)
#   adding: content/outputs/case_35.json (deflated 54%)
#   adding: content/outputs/case_65.json (deflated 34%)
#   adding: content/outputs/case_81.json (deflated 55%)
#   adding: content/outputs/case_76.json (deflated 57%)
#   adding: content/outputs/case_17.json (deflated 54%)
#   adding: content/outputs/case_31.json (deflated 53%)
#   adding: content/outputs/case_94.json (deflated 57%)
#   adding: content/outputs/case_1.json (deflated 57%)
#   adding: content/outputs/case_44.json (deflated 53%)
#   adding: content/outputs/case_3.json (deflated 55%)
#   adding: content/outputs/case_83.json (deflated 58%)
#   adding: content/outputs/case_53.json (deflated 57%)
#   adding: content/outputs/case_70.json (deflated 51%)
#   adding: content/outputs/case_56.json (deflated 34%)
#   adding: content/outputs/case_58.json (deflated 55%)
#   adding: content/outputs/case_23.json (deflated 55%)
#   adding: content/outputs/case_49.json (deflated 34%)
#   adding: content/outputs/case_63.json (deflated 59%)
#   adding: content/outputs/case_88.json (deflated 50%)
#   adding: content/outputs/case_89.json (deflated 52%)
#   adding: content/outputs/case_19.json (deflated 56%)
#   adding: content/outputs/case_24.json (deflated 56%)
#   adding: content/outputs/case_57.json (deflated 55%)
#   adding: content/outputs/case_37.json (deflated 54%)
#   adding: content/outputs/case_51.json (deflated 54%)
#   adding: content/outputs/case_32.json (deflated 56%)
#   adding: content/outputs/case_7.json (deflated 36%)
#   adding: content/outputs/case_72.json (deflated 57%)
#   adding: content/outputs/case_59.json (deflated 57%)
#   adding: content/outputs/case_10.json (deflated 34%)
#   adding: content/outputs/case_64.json (deflated 54%)
#   adding: content/outputs/case_62.json (deflated 56%)
#   adding: content/outputs/case_75.json (deflated 57%)
#   adding: content/outputs/case_68.json (deflated 34%)
#   adding: content/outputs/case_46.json (deflated 57%)
#   adding: content/outputs/case_69.json (deflated 58%)
#   adding: content/outputs/case_50.json (deflated 57%)
#   adding: content/outputs/case_77.json (deflated 58%)
#   adding: content/outputs/case_16.json (deflated 57%)
#   adding: content/outputs/case_91.json (deflated 53%)
#   adding: content/outputs/case_41.json (deflated 34%)
#   adding: content/outputs/case_29.json (deflated 53%)
#   adding: content/outputs/case_93.json (deflated 51%)
#   adding: content/outputs/case_55.json (deflated 53%)
#   adding: content/outputs/case_43.json (deflated 54%)
#   adding: content/outputs/case_33.json (deflated 54%)

# %%
from google.colab import files
files.download('/content/outputs.zip')

# %% [markdown]
# # Save to CSV

# %%
import pandas as pd
import json
from pathlib import Path

output_dir = Path("/content/outputs/")
all_records = []

for json_file in output_dir.glob("*.json"):
    with open(json_file, "r") as f:
        record = json.load(f)
        all_records.append(record)

df = pd.DataFrame(all_records)

df.to_csv("/content/moodle_93_cases.csv", index=False)

# %% [markdown]
# # Qualitative exploration

# %%
import pandas as pd
import pprint

# %%
data = pd.read_csv("/content/moodle_93_cases.csv")

# %%
data = data.dropna()

# %%
data.shape
# Out:
# (78, 6)

# %%
data.head()
# Out:
#     source                                        case_prompt  \
# 0  case_28  A 67-year-old German woman, who has lived as a...
# 2   case_5  A 4-year-old boy from Laos is presented with a...
# 3  case_78  A 42-year-old British male expatriate living i...
# 4   case_8  A 26-year-old German student presents to the c...
# 5  case_79  A 34-year-old man presents to a hospital in Ch...
#
#     final_diagnosis                                   reasoning_points  \
# 0           Loiasis  1. The patient’s history of living in an endem...
# 2              Noma  1. The rapid progression of the gangrenous les...
# 3   Trypanosomiasis  1. The patient’s presentation of anaphylactic ...
# 4           Myiasis  1. The patient’s travel history to Ghana is a ...
# 5  Strongyloidiasis  1. The patient's history of chronic diarrhea, ...
#
#                                  reasoning_narrative flagged
# 0  The diagnostic process begins with recognizing...      No
# 2  The diagnosis begins with recognizing the seve...      No
# 3  The diagnostic process begins with recognizing...      No
# 4  The diagnostic process begins with considering...      No
# 5  The diagnostic process begins with recognizing...      No

# %%
pprint.pprint(data.iloc[2]['case_prompt'])
# Out:
# ('A 42-year-old British male expatriate living in Malawi presents to the '
#  'emergency room with a florid itchy rash, difficulty in breathing, and a '
#  'feeling of impending doom. He reports a possible tick bite on his ankle 2 '
#  'days prior while walking in the countryside. Twenty-four hours after the '
#  'bite, he noticed a circumscribed, painless, indurated lesion on the inside '
#  'of his left ankle, accompanied by fever and arthralgia. A blood film for '
#  'malaria parasites was negative, and he was treated with paracetamol. On the '
#  'day of admission, he developed a widespread itchy rash and progressive '
#  'difficulty breathing. He has a family history of allergy and kept bees in '
#  'the UK without ill effect, but experienced an asthmatic attack after insect '
#  'bites at Lake Malawi 9 months ago.\n'
#  '\n'
#  'On examination, he is clammy, in a state of collapse, and has a widespread '
#  'urticarial rash. He exhibits respiratory distress and stridor. There is an '
#  'indurated circumscribed swelling on the inside of his left ankle (Fig. '
#  '78.1). His vital signs are: temperature 38°C, pulse rate 130 bpm, systolic '
#  'blood pressure 60 mmHg. Chest auscultation reveals expiratory wheezes.\n'
#  '\n'
#  'Laboratory results show: hemoglobin 17.4 g/dL; white cell count 6.1 G/L '
#  '(polymorphs 85%, lymphocytes 10%); erythrocyte sedimentation rate 5 mm/hour; '
#  'blood film negative for malaria parasites; chest radiograph normal; stool '
#  'and urine microscopy negative.\n'
#  '\n'
#  'Based on the clinical history and examination and investigations done, what '
#  'are the possible causes of this man’s illness?')

# %%
for i in range(len(data)):
  source = data.iloc[i]['source']

  data_filter = data[data['source'] == source]

  print(f"{source}'s case prompt appear {len(data_filter)} times")
# Out:
# case_28's case prompt appear 1 times
# case_5's case prompt appear 1 times
# case_78's case prompt appear 1 times
# case_8's case prompt appear 1 times
# case_79's case prompt appear 1 times
# case_80's case prompt appear 1 times
# case_92's case prompt appear 1 times
# case_61's case prompt appear 1 times
# case_47's case prompt appear 1 times
# case_20's case prompt appear 1 times
# case_74's case prompt appear 1 times
# case_60's case prompt appear 1 times
# case_11's case prompt appear 1 times
# case_90's case prompt appear 1 times
# case_71's case prompt appear 1 times
# case_6's case prompt appear 1 times
# case_54's case prompt appear 1 times
# case_42's case prompt appear 1 times
# case_52's case prompt appear 1 times
# case_39's case prompt appear 1 times
# case_14's case prompt appear 1 times
# case_67's case prompt appear 1 times
# case_66's case prompt appear 1 times
# case_85's case prompt appear 1 times
# case_30's case prompt appear 1 times
# case_82's case prompt appear 1 times
# case_73's case prompt appear 1 times
# case_38's case prompt appear 1 times
# case_87's case prompt appear 1 times
# case_9's case prompt appear 1 times
# case_13's case prompt appear 1 times
# case_2's case prompt appear 1 times
# case_27's case prompt appear 1 times
# case_4's case prompt appear 1 times
# case_25's case prompt appear 1 times
# case_15's case prompt appear 1 times
# case_22's case prompt appear 1 times
# case_21's case prompt appear 1 times
# case_48's case prompt appear 1 times
# case_35's case prompt appear 1 times
# case_81's case prompt appear 1 times
# case_76's case prompt appear 1 times
# case_17's case prompt appear 1 times
# case_31's case prompt appear 1 times
# case_94's case prompt appear 1 times
# case_1's case prompt appear 1 times
# case_44's case prompt appear 1 times
# case_3's case prompt appear 1 times
# case_83's case prompt appear 1 times
# case_53's case prompt appear 1 times
# case_70's case prompt appear 1 times
# case_58's case prompt appear 1 times
# case_23's case prompt appear 1 times
# case_63's case prompt appear 1 times
# case_88's case prompt appear 1 times
# case_89's case prompt appear 1 times
# case_19's case prompt appear 1 times
# case_24's case prompt appear 1 times
# case_57's case prompt appear 1 times
# case_37's case prompt appear 1 times
# case_51's case prompt appear 1 times
# case_32's case prompt appear 1 times
# case_72's case prompt appear 1 times
# case_59's case prompt appear 1 times
# case_64's case prompt appear 1 times
# case_62's case prompt appear 1 times
# case_75's case prompt appear 1 times
# case_46's case prompt appear 1 times
# case_69's case prompt appear 1 times
# case_50's case prompt appear 1 times
# case_77's case prompt appear 1 times
# case_16's case prompt appear 1 times
# case_91's case prompt appear 1 times
# case_29's case prompt appear 1 times
# case_93's case prompt appear 1 times
# case_55's case prompt appear 1 times
# case_43's case prompt appear 1 times
# case_33's case prompt appear 1 times

# %%
print(f"Number of unique sources: {data['case_prompt'].nunique()}")
print(f"Total number of rows: {len(data)}")
# Out:
# Number of unique sources: 78
# Total number of rows: 78

# %%
data.iloc[3]['source']
# Out:
# 'case_8'

# %%
pprint.pprint(data.iloc[2]['reasoning_narrative'])
# Out:
# ('The diagnostic process begins with recognizing the acute anaphylactic shock, '
#  'prompting consideration of allergic reactions and tick-borne illnesses. The '
#  'patient’s history of allergy and recent tick bite strongly support this '
#  'initial line of reasoning. However, the negative malaria smear and normal '
#  'chest radiograph help to exclude common infectious causes of fever and '
#  'respiratory distress. The presence of an indurated lesion at the bite site '
#  'suggests a localized inflammatory response, but also raises the possibility '
#  'of an underlying infectious process. The initial investigations, while '
#  'ruling out some common causes, do not definitively confirm a diagnosis, '
#  'necessitating further evaluation.')

# %% [markdown]
# # Adding image

# %%
import shutil
import os

os.makedirs("/content/benchmark_image", exist_ok=True)

for i in range(len(data)):
  source = data.iloc[i]['source']
  question = data.iloc[i]['case_prompt']

  # Filter image-path pair
  with open(f"/content/extracted_case_report_image_filtered/{source}/auto/{source}.md") as f:
    content = f.read()

  image_path_pattern = r'(Fig\.\s*\d+\.?\d*)\s*!\[\]\((images/[a-f0-9]+\.jpg)\)'
  image_path_pairs = list(set(re.findall(image_path_pattern, content))) # Remove duplicates

  # Filter figure mention
  figure_pattern = r'(Fig\.\s*\d+\.?\d*)'

  # Check if question is a string before applying re.findall
  if isinstance(question, str):
    figures = list(set(re.findall(figure_pattern, question)))
  else:
    figures = [] # Assign an empty list if question is not a string

  print(source)
  print(image_path_pairs)
  print(figures)

  # Include images
  if image_path_pairs and figures:
    os.makedirs(f"/content/benchmark_image/{source}", exist_ok=True)

    for figure in figures:
      for fig_name, img_path in image_path_pairs:
        if figure == fig_name:
          shutil.copy(f"/content/extracted_case_report_image_filtered/{source}/auto/{img_path}", f"/content/benchmark_image/{source}/{figure}.jpg")
          print(f"Image path for {figure}: {img_path}")
  else:
    print(f"{source} question has no image")

  print()
# Out:
# case_28
# [('Fig. 28.1', 'images/06c88e3d40a3873766a2c875b7b4e7b535bb71f54b35d0ecb3477ffba4e3c4f2.jpg'), ('Fig. 28.2', 'images/6e2b31464663e02238303fdc59314c4f5bf564ddbfc7211351da79865daa8419.jpg')]
# []
# case_28 question has no image
#
# case_5
# [('Fig. 5.2', 'images/73dc5c3c71f492b5440114a4623f5dbdb131619a3c5ef4cea045a7aebab6baa9.jpg'), ('Fig. 5.1', 'images/b29955d6809c7bea6a2b79afc1f334d8e6514e5d123dd6e95448da2bd2b5831a.jpg')]
# ['Fig. 5.1']
# Image path for Fig. 5.1: images/b29955d6809c7bea6a2b79afc1f334d8e6514e5d123dd6e95448da2bd2b5831a.jpg
#
# case_78
# [('Fig. 78.1', 'images/d7426c7c2f79fe35697383f20a96d55dcb96378236ff2eac1fa67e6fd207e3a8.jpg'), ('Fig. 78.2', 'images/579a3fee879f9ec1ce955ede51e35ba279919050a2a725849a34df45bf69389c.jpg')]
# ['Fig. 78.1']
# Image path for Fig. 78.1: images/d7426c7c2f79fe35697383f20a96d55dcb96378236ff2eac1fa67e6fd207e3a8.jpg
#
# case_8
# [('Fig. 8.1', 'images/5432e9a71548f4edc081d0677dca83f29a882cdfb5a803ed8531b52f9f4c1e0c.jpg'), ('Fig. 8.2', 'images/cbefa26063060dcba1f2b399cd6c85c68ee825ebff8ad9481f83e7474d574f70.jpg')]
# ['Fig. 8.1']
# Image path for Fig. 8.1: images/5432e9a71548f4edc081d0677dca83f29a882cdfb5a803ed8531b52f9f4c1e0c.jpg
#
# case_79
# [('Fig. 79.2', 'images/a5b8ac8cddf8cb9faad9f3f59ca0aabaf909b8d6f9cd3eecbe575baaec6cbfb8.jpg'), ('Fig. 79.1', 'images/622b08f81b7a9de57292c3d3a7f5c2153c8afee10004ddededb15287c066d0c6.jpg')]
# ['Fig. 79.1']
# Image path for Fig. 79.1: images/622b08f81b7a9de57292c3d3a7f5c2153c8afee10004ddededb15287c066d0c6.jpg
#
# case_80
# [('Fig. 80.2', 'images/d57fc02bde9d9f9d1ae15377039b36367910efecdbacb0f0628cbf5d44e7a872.jpg'), ('Fig. 80.1', 'images/ff47257b62fa08614108fabdc4f21794dd0110ac0f3a1dc4e23cfb404f1ce67c.jpg')]
# ['Fig. 80.1']
# Image path for Fig. 80.1: images/ff47257b62fa08614108fabdc4f21794dd0110ac0f3a1dc4e23cfb404f1ce67c.jpg
#
# case_92
# [('Fig. 92.2', 'images/386e85c815f94b36480135db3f169b5a6aba341d24f94c58b310376096646c79.jpg'), ('Fig. 92.1', 'images/f55740271d73974b32707919ef3bcb3125376e86b8346e849ab28021d69958e6.jpg')]
# []
# case_92 question has no image
#
# case_61
# [('Fig. 61.2', 'images/d7f315d3ef9f9d9eb8067c4ccc9c15348d5135bb5ca5425697f0e368557c13a5.jpg'), ('Fig. 61.1', 'images/8910db4d60b3e19f3137eba8200856585801f1e0aa7764698abbb94f18b8ad55.jpg')]
# ['Fig. 61.2', 'Fig. 61.1']
# Image path for Fig. 61.2: images/d7f315d3ef9f9d9eb8067c4ccc9c15348d5135bb5ca5425697f0e368557c13a5.jpg
# Image path for Fig. 61.1: images/8910db4d60b3e19f3137eba8200856585801f1e0aa7764698abbb94f18b8ad55.jpg
#
# case_47
# [('Fig. 47.1', 'images/0fdac081de1b5a64ff669beb6ef7a9a20795cacfc45178a1c8e8be3024fc9075.jpg'), ('Fig. 47.2', 'images/df892f21138f0bf6a7cbda2aff93dace4f638d42ef4fce9eb723fb81c3b855f0.jpg')]
# ['Fig. 47.2']
# Image path for Fig. 47.2: images/df892f21138f0bf6a7cbda2aff93dace4f638d42ef4fce9eb723fb81c3b855f0.jpg
#
# case_20
# [('Fig. 20.1', 'images/cc156651276182f31b9ecd624f2e543d607f42a2a7eb02ecdbabbee425fd0a34.jpg'), ('Fig. 20.2', 'images/44541c8889bf2d3568c806a5de9afb106dfd58ee9ef105cc6cc94f17e63e06c8.jpg')]
# ['Fig. 20.1']
# Image path for Fig. 20.1: images/cc156651276182f31b9ecd624f2e543d607f42a2a7eb02ecdbabbee425fd0a34.jpg
# Image path for Fig. 54.1: images/d40e64b9006aeb648ca3fb713859062c2e641463161884773eefd64b94f63718.jpg
#
# case_42
# [('Fig. 42.1', 'images/72fede3aeec88d095d9269a370abf089b8fcfafd888f2a88c1ae233209252568.jpg')]
# ['Fig. 42.1']
# Image path for Fig. 42.1: images/72fede3aeec88d095d9269a370abf089b8fcfafd888f2a88c1ae233209252568.jpg
#
# case_52
# [('Fig. 52.2', 'images/1e3ccfc5f962c048cd9da6ed83a61c07947716485a8fe8ec8986792487a01c03.jpg'), ('Fig. 52.1', 'images/cff153124df86177332bb48967b15052dffdf61d9abf9146358546e54e664799.jpg')]
# []
# case_52 question has no image
#
# case_39
# [('Fig. 39.1', 'images/f51a30af509ac618fe0af8e258206e616f9bcf7d9d9a61841c23c8bc04993c98.jpg')]
# []
# case_39 question has no image
#
# case_14
# [('Fig. 14.1', 'images/c5264686883788becd4a6e312dfafac8a0524dbd738ac7de75a8223dac0d5d40.jpg')]
# ['Fig. 14.1']
# Image path for Fig. 14.1: images/c5264686883788becd4a6e312dfafac8a0524dbd738ac7de75a8223dac0d5d40.jpg
#
# case_67
# [('Fig. 67.1', 'images/ec3c7b58dfc6a8bf1bad519be274eadd1a49d2978d74f6004e48688315f35126.jpg')]
# ['Fig. 67.1']
# Image path for Fig. 67.1: images/ec3c7b58dfc6a8bf1bad519be274eadd1a49d2978d74f6004e48688315f35126.jpg
#
# case_66
# [('Fig. 66.1', 'images/2c40e5f7bea2b2c7c3839e9bf5818421605cb045d624b577a71d74c5753cd3d2.jpg')]
# ['Fig. 66.1']
# Image path for Fig. 66.1: images/2c40e5f7bea2b2c7c3839e9bf5818421605cb045d624b577a71d74c5753cd3d2.jpg
#
# case_85
# [('Fig. 85.2', 'images/73e4c29bcf3d2a74d6455d8343cec181fe85af4135385aa181f52c44fe80886a.jpg'), ('Fig. 85.1', 'images/49b94bc12890810f7f8a9c8a260c966fe2f67b10165fa8b0a831458ba2cec00f.jpg')]
# ['Fig. 85.1', 'Fig. 85.2']
# Image path for Fig. 85.1: images/49b94bc12890810f7f8a9c8a260c966fe2f67b10165fa8b0a831458ba2cec00f.jpg
# Image path for Fig. 85.2: images/73e4c29bcf3d2a74d6455d8343cec181fe85af4135385aa181f52c44fe80886a.jpg
#
# case_30
# [('Fig. 30.1', 'images/f47b9fe5d395e0839ef51164dc18a74e4d2c7f5e7f29d18d33b2241c064ca9a6.jpg'), ('Fig. 30.2', 'images/b7e06fafddf6114afac1027750f863479e2038b676bd44cd124afca42599f2dc.jpg')]
# ['Fig. 30.2', 'Fig. 30.1']
# Image path for Fig. 30.2: images/b7e06fafddf6114afac1027750f863479e2038b676bd44cd124afca42599f2dc.jpg
# Image path for Fig. 30.1: images/f47b9fe5d395e0839ef51164dc18a74e4d2c7f5e7f29d18d33b2241c064ca9a6.jpg
#
# case_82
# [('Fig. 82.2', 'images/edff6995693f98bf52b41dc697718c7158251bb7927bc00a95c365864dd29f23.jpg'), ('Fig. 82.1', 'images/fc3c1819b8cacbf4e7350560782325140d6f1a2ebe6bb11c4d10df9c5fc6ee2b.jpg')]
# ['Fig. 82.2', 'Fig. 82.1']
# Image path for Fig. 82.2: images/edff6995693f98bf52b41dc697718c7158251bb7927bc00a95c365864dd29f23.jpg
# Image path for Fig. 82.1: images/fc3c1819b8cacbf4e7350560782325140d6f1a2ebe6bb11c4d10df9c5fc6ee2b.jpg
#
# case_73
# []
# []
# case_73 question has no image
#
# case_38
# [('Fig. 38.1', 'images/dbd8b39d45efcb78065515188b406d6dc395e7ce7f121811c4b1cb375be1779c.jpg')]
# ['Fig. 38.1']
# Image path for Fig. 38.1: images/dbd8b39d45efcb78065515188b406d6dc395e7ce7f121811c4b1cb375be1779c.jpg
#
# case_87
# []
# []
# case_87 question has no image
#
# case_9
# []
# []
# case_9 question has no image
#
# case_13
# []
# []
# case_13 question has no image
#
# case_2
# [('Fig. 2.1', 'images/23a72054528d5312fc3b23998553da39b228805615da5d2c18740d050ba39ad7.jpg'), ('Fig. 2.3', 'images/980dcaadd9c9c6992b9a3d3b30558dc833da9921c8e015c490244fe0ffe7ca10.jpg'), ('Fig. 2.2', 'images/35070e29ee60a6b0a8111c0646e42c72df64c7c5ce712dc3b3ccb3a5b13517e0.jpg')]
# ['Fig. 2.1']
# Image path for Fig. 2.1: images/23a72054528d5312fc3b23998553da39b228805615da5d2c18740d050ba39ad7.jpg
#
# case_27
# [('Fig. 27.1', 'images/49d23cf6faba409df4f9a21868c0d453590a17499e59458a376261e9f1a853c5.jpg')]
# ['Fig. 27.1']
# Image path for Fig. 27.1: images/49d23cf6faba409df4f9a21868c0d453590a17499e59458a376261e9f1a853c5.jpg
#
# case_4
# [('Fig. 4.1', 'images/ef25f2d3d8da5f8217d8d257a0e73c517dd4c4d90e4154fb1aa045a42cc8bf62.jpg'), ('Fig. 4.2', 'images/acf6d053ad4cd61a1c50044a81090154c93027dd06879030aee43bc6f4df682f.jpg')]
# []
# case_4 question has no image
#
# case_25
# [('Fig. 25.1', 'images/87aec159e3b580f5537724b01c4cf0ef092d69879b4132c2deabaf2be3464e14.jpg'), ('Fig. 25.2', 'images/4303eaa09c49b14420a783a42aad0e6eb9c1e55e44b6ac238507b942985cd9dc.jpg')]
# ['Fig. 25.1']
# Image path for Fig. 25.1: images/87aec159e3b580f5537724b01c4cf0ef092d69879b4132c2deabaf2be3464e14.jpg
#
# case_15
# [('Fig. 15.1', 'images/582be9be99e7807d56ce80eb551c8623986861ad384a56db4d044884f13faa9b.jpg')]
# ['Fig. 15.1']
# Image path for Fig. 15.1: images/582be9be99e7807d56ce80eb551c8623986861ad384a56db4d044884f13faa9b.jpg
#
# case_22
# [('Fig. 22.1', 'images/e1a0cee8f80978b04aba1a44dd7ecb73ab7019bf6b14d2e9d439f9831df274d6.jpg')]
# []
# case_22 question has no image
#
# case_21
# [('Fig. 21.1', 'images/f39573ff56393c3ee0e811970bd5914b7d8b595792437f014d8ae248a510de88.jpg')]
# ['Fig. 21.1']
# Image path for Fig. 21.1: images/f39573ff56393c3ee0e811970bd5914b7d8b595792437f014d8ae248a510de88.jpg
#
# case_48
# [('Fig. 48.1', 'images/d4f1eb57b9ba5bb1b1420445be536236cea9bfabe88680330add9ddd29d6629f.jpg')]
# ['Fig. 48.1']
# Image path for Fig. 48.1: images/d4f1eb57b9ba5bb1b1420445be536236cea9bfabe88680330add9ddd29d6629f.jpg
#
# case_35
# [('Fig. 35.1', 'images/345423f0f719a1f4cfac03242531f0e82d255b7e8aebc40d64672fbd3638037e.jpg'), ('Fig. 35.2', 'images/0398215d3275be58800183ec6c96cf0467e9bff4ceb1e8665c76f0d2558b693b.jpg')]
# ['Fig. 35.1']
# Image path for Fig. 35.1: images/345423f0f719a1f4cfac03242531f0e82d255b7e8aebc40d64672fbd3638037e.jpg
#
# case_81
# [('Fig. 81.1', 'images/acd1d112b8d6e9eb0376d062e506f92750d8397600e002954a9168d692933346.jpg')]
# ['Fig. 81.1']
# Image path for Fig. 81.1: images/acd1d112b8d6e9eb0376d062e506f92750d8397600e002954a9168d692933346.jpg
#
# case_76
# [('Fig. 76.1', 'images/0a5160a8ff27dd6ad3728cfb8f456985da0ee1b6b0f092fdfb75f8db04e43f92.jpg')]
# []
# case_76 question has no image
#
# case_17
# [('Fig. 17.1', 'images/71c7e04860764bc9f3dfd62f1811f3c69a37f81d7312069d24e008e193f37143.jpg'), ('Fig. 17.2', 'images/5e25d9961c03ad0ed5a70fde4a2b5c1b6bb775554e21cfa1a7e852c937716b1b.jpg')]
# ['Fig. 17.1']
# Image path for Fig. 17.1: images/71c7e04860764bc9f3dfd62f1811f3c69a37f81d7312069d24e008e193f37143.jpg
#
# case_31
# [('Fig. 31.1', 'images/cf83f71d36182b56bfedd94fed45feb93781ccb8d9156c14b8d38866e6b10a3c.jpg')]
# []
# case_31 question has no image
#
# case_94
# [('Fig. 94.2', 'images/b5971e6f297245381ff82a1b26d76958300f606813d04fb03d1570b71504ac09.jpg'), ('Fig. 94.1', 'images/5806c9ac5b39968185f57e4b5a81b0ead2e30cfbad71e6aac363ed459bfae4a6.jpg')]
# ['Fig. 94.1']
# Image path for Fig. 94.1: images/5806c9ac5b39968185f57e4b5a81b0ead2e30cfbad71e6aac363ed459bfae4a6.jpg
#
# case_1
# [('Fig. 1.2', 'images/1026c4b35dde2d99971dcf146db97445e5335115ce9dadb6badc26a4bd9c2bf0.jpg'), ('Fig. 1.1', 'images/7274b7728e7b81d6b41e77ffc5319fe8370be1602c7074a0c6b99b9812a37ded.jpg')]
# ['Fig. 1.2', 'Fig. 1.1']
# Image path for Fig. 1.2: images/1026c4b35dde2d99971dcf146db97445e5335115ce9dadb6badc26a4bd9c2bf0.jpg
# Image path for Fig. 1.1: images/7274b7728e7b81d6b41e77ffc5319fe8370be1602c7074a0c6b99b9812a37ded.jpg
#
# case_44
# [('Fig. 44.1', 'images/ba9a0dfed765d35ccdb52668619035e5b0f6d33c5b3736aa25a83d5562af7e2b.jpg')]
# []
# case_44 question has no image
#
# case_3
# [('Fig. 3.2', 'images/336c1420b61067c4d805d66ecd7102f5b613732db66d275207816a6cbab6c369.jpg'), ('Fig. 3.1', 'images/dca6f83924fe5de9471a204fd2ff4f83b33275d7e3f63bd1f11bec59db73a25d.jpg')]
# ['Fig. 3.1']
# Image path for Fig. 3.1: images/dca6f83924fe5de9471a204fd2ff4f83b33275d7e3f63bd1f11bec59db73a25d.jpg
#
# case_83
# [('Fig. 83.1', 'images/1cee86dd12e7c7c33b29baf47607e17c33e221fce7b88a0ac4de093640264023.jpg')]
# ['Fig. 83.1']
# Image path for Fig. 83.1: images/1cee86dd12e7c7c33b29baf47607e17c33e221fce7b88a0ac4de093640264023.jpg
#
# case_53
# []
# []
# case_53 question has no image
#
# case_70
# []
# []
# case_70 question has no image
#
# case_58
# [('Fig. 58.2', 'images/05cdd1177ac2eae385553811cec637f141bfae60285e39abbb95bc9c87097a12.jpg'), ('Fig. 58.1', 'images/ed24f94a689d80e55c3502e2436649aa7128a306dfaf8cd88f17bc2f0a0f2d4f.jpg')]
# ['Fig. 58.1']
# Image path for Fig. 58.1: images/ed24f94a689d80e55c3502e2436649aa7128a306dfaf8cd88f17bc2f0a0f2d4f.jpg
#
# case_23
# [('Fig. 23.1', 'images/d45007e1f6d23554e380c0913b933195aa20264bee5bdb30e99223ed45f9a1a2.jpg'), ('Fig. 23.2', 'images/f47886d4777b3b9efc0b66f62df9a4c870b1255a4e1b05a96944d31b31685a84.jpg')]
# ['Fig. 23.1']
# Image path for Fig. 23.1: images/d45007e1f6d23554e380c0913b933195aa20264bee5bdb30e99223ed45f9a1a2.jpg
#
# case_63
# [('Fig. 63.1', 'images/0c01d79b85e8a959494378004792e8458b47874775d6d97ddadb6325b5c859a8.jpg')]
# ['Fig. 63.1']
# Image path for Fig. 63.1: images/0c01d79b85e8a959494378004792e8458b47874775d6d97ddadb6325b5c859a8.jpg
#
# case_88
# []
# []
# case_88 question has no image
#
# case_89
# [('Fig. 89.1', 'images/18925c1e3c85d3eb6aef69219e402e853868cc46bf8e531d55947d4a51e42aad.jpg'), ('Fig. 89.2', 'images/58a6421f40cdd880ef696d0bb6a5fb9cddc7920f0e56e738e3adacf8003650cb.jpg')]
# ['Fig. 89.1']
# Image path for Fig. 89.1: images/18925c1e3c85d3eb6aef69219e402e853868cc46bf8e531d55947d4a51e42aad.jpg
#
# case_19
# [('Fig. 19.2', 'images/b801ee57fdda6538ff01e6f74775c5b44223d72273a87b8ed8e88871a8d72012.jpg'), ('Fig. 19.1', 'images/3c543edc5a17a12dae4f615276fd695dd6b2224fc66cd634eda3d3926880d831.jpg')]
# ['Fig. 19.1', 'Fig. 19.2']
# Image path for Fig. 19.1: images/3c543edc5a17a12dae4f615276fd695dd6b2224fc66cd634eda3d3926880d831.jpg
# Image path for Fig. 19.2: images/b801ee57fdda6538ff01e6f74775c5b44223d72273a87b8ed8e88871a8d72012.jpg
#
# case_24
# [('Fig. 24.1', 'images/c311ed158dfe59cfb06ba75ee98d3c3c46f758c0b5b6159ec63c7782fa26fad6.jpg')]
# ['Fig. 24.1']
# Image path for Fig. 24.1: images/c311ed158dfe59cfb06ba75ee98d3c3c46f758c0b5b6159ec63c7782fa26fad6.jpg
#
# case_57
# [('Fig. 57.1', 'images/178b6982a035f5f4d0365ef214daa78a224559a40cda6f36c0b92543810e5b3c.jpg')]
# ['Fig. 57.1']
# Image path for Fig. 57.1: images/178b6982a035f5f4d0365ef214daa78a224559a40cda6f36c0b92543810e5b3c.jpg
#
# case_37
# [('Fig. 37.1', 'images/07d35f1748dd80381154ba9c8202e67afc6c07b23a9ca54b311532ff820ed7cc.jpg'), ('Fig. 37.2', 'images/0d254210c31ad05ec2ca412e43cac87d446fd592983a9727dd5249c63c847f24.jpg')]
# ['Fig. 37.2', 'Fig. 37.1']
# Image path for Fig. 37.2: images/0d254210c31ad05ec2ca412e43cac87d446fd592983a9727dd5249c63c847f24.jpg
# Image path for Fig. 37.1: images/07d35f1748dd80381154ba9c8202e67afc6c07b23a9ca54b311532ff820ed7cc.jpg
#
# case_51
# [('Fig. 51.1', 'images/7aeca3da317d15ae7442fb4ff8d47ff571fc54aa80661e2ee13ce2dd5d193c95.jpg'), ('Fig. 51.2', 'images/01d9dede64cb4a68525a9f26ed90ac9c3e68c5899e639062f3f988d265bc4818.jpg')]
# ['Fig. 51.1']
# Image path for Fig. 51.1: images/7aeca3da317d15ae7442fb4ff8d47ff571fc54aa80661e2ee13ce2dd5d193c95.jpg
#
# case_32
# [('Fig. 32.2', 'images/c215cafdf159debafab570b7f5dd792638c5a7adedfe1f46e6131581443cbafd.jpg'), ('Fig. 32.1', 'images/5502698002beeb8651edc3e51ba06225d84a8cd59ba8ed3505ca6850c4ab6f3c.jpg')]
# ['Fig. 32.1']
# Image path for Fig. 32.1: images/5502698002beeb8651edc3e51ba06225d84a8cd59ba8ed3505ca6850c4ab6f3c.jpg
#
# case_72
# [('Fig. 72.2', 'images/2d789b435a74091af421c14ff00a37e1eb0b23cfec9c75fa48d28c4b22c8a6a5.jpg'), ('Fig. 72.1', 'images/886feca3d1f7e1b04003d695d7353d1a49298a04c5109b6c28cfdfdac6284668.jpg')]
# ['Fig. 72.1', 'Fig. 72.2']
# Image path for Fig. 72.1: images/886feca3d1f7e1b04003d695d7353d1a49298a04c5109b6c28cfdfdac6284668.jpg
# Image path for Fig. 72.2: images/2d789b435a74091af421c14ff00a37e1eb0b23cfec9c75fa48d28c4b22c8a6a5.jpg
#
# case_59
# [('Fig. 59.1', 'images/15b09d3ddf1c8629ae7e815edfb0bb544e8128fcc2400f8b775a71d00a9f756e.jpg'), ('Fig. 59.2', 'images/f4869c74c26a3379c59aff967535e18e99e9246256d354b109b7ecf6ba68a236.jpg'), ('Fig. 59.3', 'images/1d71a1b7f6bfdd08aeea65d84a8445679cc04f3fd24e580bb1ee88223c613a9f.jpg')]
# ['Fig. 59.3', 'Fig. 59.2', 'Fig. 59.1']
# Image path for Fig. 59.3: images/1d71a1b7f6bfdd08aeea65d84a8445679cc04f3fd24e580bb1ee88223c613a9f.jpg
# Image path for Fig. 59.2: images/f4869c74c26a3379c59aff967535e18e99e9246256d354b109b7ecf6ba68a236.jpg
# Image path for Fig. 59.1: images/15b09d3ddf1c8629ae7e815edfb0bb544e8128fcc2400f8b775a71d00a9f756e.jpg
#
# case_64
# [('Fig. 64.1', 'images/c70ca3efbd8d39536c572b5fecc4cf7f706ac0b5580cdab2a6767df9561f6e44.jpg')]
# []
# case_64 question has no image
#
# case_62
# [('Fig. 62.1', 'images/47d7d65e4b185923bb0f2115247aa24e0c2523de599ceec03f36f38ad7941110.jpg'), ('Fig. 62.2', 'images/4524fb7fd988ee3ebfb6821c1521675aebb01ab029abcfbf0c472943e66e400b.jpg')]
# ['Fig. 62.1', 'Fig. 62.2']
# Image path for Fig. 62.1: images/47d7d65e4b185923bb0f2115247aa24e0c2523de599ceec03f36f38ad7941110.jpg
# Image path for Fig. 62.2: images/4524fb7fd988ee3ebfb6821c1521675aebb01ab029abcfbf0c472943e66e400b.jpg
#
# case_75
# [('Fig. 75.2', 'images/798256adc6c0501e5dba1f56fc11cf04c75f0a4297af9b5655a4b62c16aed503.jpg'), ('Fig. 75.1', 'images/1421a6bffcb1980ce1edd2b1444490cf0845ee3d427c01a84ccfd6729ac57ea8.jpg')]
# ['Fig. 75.1', 'Fig. 75.2']
# Image path for Fig. 75.1: images/1421a6bffcb1980ce1edd2b1444490cf0845ee3d427c01a84ccfd6729ac57ea8.jpg
# Image path for Fig. 75.2: images/798256adc6c0501e5dba1f56fc11cf04c75f0a4297af9b5655a4b62c16aed503.jpg
#
# case_46
# []
# []
# case_46 question has no image
#
# case_69
# [('Fig. 69.2', 'images/820a87d11596273e013bab52911ac52019eaa6523206cd58cf26bad5916e0184.jpg'), ('Fig. 69.1', 'images/7d5c5dfc272e2e304bf0619feefcbc2e9f9431ecbeef652da116ba5488ecd9a3.jpg')]
# ['Fig. 69.2', 'Fig. 69.1']
# Image path for Fig. 69.2: images/820a87d11596273e013bab52911ac52019eaa6523206cd58cf26bad5916e0184.jpg
# Image path for Fig. 69.1: images/7d5c5dfc272e2e304bf0619feefcbc2e9f9431ecbeef652da116ba5488ecd9a3.jpg
#
# case_50
# [('Fig. 50.1', 'images/4b96a28853ebc5448932121f3854a47864880b7f9e6a0c798af105ec135d5368.jpg'), ('Fig. 50.2', 'images/433216a9e1be390306277169d3395a2e354668aa1218c4eb82d5841f47b2328e.jpg')]
# ['Fig. 50.2', 'Fig. 50.1']
# Image path for Fig. 50.2: images/433216a9e1be390306277169d3395a2e354668aa1218c4eb82d5841f47b2328e.jpg
# Image path for Fig. 50.1: images/4b96a28853ebc5448932121f3854a47864880b7f9e6a0c798af105ec135d5368.jpg
#
# case_77
# [('Fig. 77.1', 'images/f73249f47fd6ce70093cbbae1bd50751397db68b3fcc2a0565ffceb3d1663eff.jpg'), ('Fig. 77.2', 'images/2681941950661f6f6eb86024b15a9a75daf0d405343c013bc7e8ea6c773abb49.jpg')]
# ['Fig. 77.1']
# Image path for Fig. 77.1: images/f73249f47fd6ce70093cbbae1bd50751397db68b3fcc2a0565ffceb3d1663eff.jpg
#
# case_16
# []
# []
# case_16 question has no image
#
# case_91
# []
# []
# case_91 question has no image
#
# case_29
# []
# []
# case_29 question has no image
#
# case_93
# [('Fig. 93.2', 'images/4a1c83e2b62a9c7b953f9b9f86462c6911bc2db77470dbfbfe6c46b738a8732d.jpg'), ('Fig. 93.1', 'images/13195721e1db7f755e2c073cfe07d21a6a2a0775761538a6262d2122435270ba.jpg')]
# ['Fig. 93.1']
# Image path for Fig. 93.1: images/13195721e1db7f755e2c073cfe07d21a6a2a0775761538a6262d2122435270ba.jpg
#
# case_55
# [('Fig. 55.1', 'images/744ad2762e8eae55cf95619444ba36e0ab62b0e92ed0fc746172e0bfd15dab45.jpg'), ('Fig. 55.2', 'images/bfe47fa9d6971672baa976ce25fdb05f65515180eab97a74884922f7b00f2a5c.jpg')]
# ['Fig. 55.1']
# Image path for Fig. 55.1: images/744ad2762e8eae55cf95619444ba36e0ab62b0e92ed0fc746172e0bfd15dab45.jpg
#
# case_43
# [('Fig. 43.2', 'images/ea4d82026fd6820128578fb38b8f639d357a9f04d3c5490cabde5a09f844cacb.jpg'), ('Fig. 43.1', 'images/420f592f126156706fde7223810a646d77f82503faaa5600a75c1a3ccfd8471c.jpg')]
# ['Fig. 43.1']
# Image path for Fig. 43.1: images/420f592f126156706fde7223810a646d77f82503faaa5600a75c1a3ccfd8471c.jpg
#
# case_33
# [('Fig. 33.1', 'images/ef3cd96d8a6d24181f5a4e9a6342ddcba42f32d1c2aeb2ce33ca5f7ca70c1df2.jpg'), ('Fig. 33.2', 'images/276b4e94ebca6978aa56ef37bd43217b606d032a60bef652dfe3076376e52203.jpg')]
# ['Fig. 33.1']
# Image path for Fig. 33.1: images/ef3cd96d8a6d24181f5a4e9a6342ddcba42f32d1c2aeb2ce33ca5f7ca70c1df2.jpg

# %%
# !zip -r /content/benchmark_image.zip /content/benchmark_image/
# Out:
#   adding: content/benchmark_image/ (stored 0%)
#   adding: content/benchmark_image/case_75/ (stored 0%)
#   adding: content/benchmark_image/case_75/Fig. 75.1.jpg (deflated 4%)
#   adding: content/benchmark_image/case_75/Fig. 75.2.jpg (deflated 10%)
#   adding: content/benchmark_image/case_20/ (stored 0%)
#   adding: content/benchmark_image/case_20/Fig. 20.1.jpg (deflated 4%)
#   adding: content/benchmark_image/case_51/ (stored 0%)
#   adding: content/benchmark_image/case_51/Fig. 51.1.jpg (deflated 1%)
#   adding: content/benchmark_image/case_59/ (stored 0%)
#   adding: content/benchmark_image/case_59/Fig. 59.3.jpg (deflated 3%)
#   adding: content/benchmark_image/case_59/Fig. 59.1.jpg (deflated 2%)
#   adding: content/benchmark_image/case_59/Fig. 59.2.jpg (deflated 2%)
#   adding: content/benchmark_image/case_63/ (stored 0%)
#   adding: content/benchmark_image/case_63/Fig. 63.1.jpg (deflated 2%)
#   adding: content/benchmark_image/case_57/ (stored 0%)
#   adding: content/benchmark_image/case_57/Fig. 57.1.jpg (deflated 2%)
#   adding: content/benchmark_image/case_69/ (stored 0%)
#   adding: content/benchmark_image/case_69/Fig. 69.2.jpg (deflated 1%)
#   adding: content/benchmark_image/case_69/Fig. 69.1.jpg (deflated 1%)
#   adding: content/benchmark_image/case_60/ (stored 0%)
#   adding: content/benchmark_image/case_60/Fig. 60.1.jpg (deflated 2%)
#   adding: content/benchmark_image/case_58/ (stored 0%)
#   adding: content/benchmark_image/case_58/Fig. 58.1.jpg (deflated 1%)
#   adding: content/benchmark_image/case_55/ (stored 0%)
#   adding: content/benchmark_image/case_55/Fig. 55.1.jpg (deflated 2%)
#   adding: content/benchmark_image/case_19/ (stored 0%)
#   adding: content/benchmark_image/case_19/Fig. 19.2.jpg (deflated 0%)
#   adding: content/benchmark_image/case_19/Fig. 19.1.jpg (deflated 3%)
#   adding: content/benchmark_image/case_14/ (stored 0%)
#   adding: content/benchmark_image/case_14/Fig. 14.1.jpg (deflated 3%)
#   adding: content/benchmark_image/case_67/ (stored 0%)
#   adding: content/benchmark_image/case_67/Fig. 67.1.jpg (deflated 2%)
#   adding: content/benchmark_image/case_23/ (stored 0%)
#   adding: content/benchmark_image/case_23/Fig. 23.1.jpg (deflated 3%)
#   adding: content/benchmark_image/case_50/ (stored 0%)
#   adding: content/benchmark_image/case_50/Fig. 50.2.jpg (deflated 4%)
#   adding: content/benchmark_image/case_50/Fig. 50.1.jpg (deflated 9%)
#   adding: content/benchmark_image/case_17/ (stored 0%)
#   adding: content/benchmark_image/case_17/Fig. 17.1.jpg (deflated 1%)
#   adding: content/benchmark_image/case_61/ (stored 0%)
#   adding: content/benchmark_image/case_61/Fig. 61.2.jpg (deflated 12%)
#   adding: content/benchmark_image/case_61/Fig. 61.1.jpg (deflated 1%)
#   adding: content/benchmark_image/case_38/ (stored 0%)
#   adding: content/benchmark_image/case_38/Fig. 38.1.jpg (deflated 8%)
#   adding: content/benchmark_image/case_5/ (stored 0%)
#   adding: content/benchmark_image/case_5/Fig. 5.1.jpg (deflated 1%)
#   adding: content/benchmark_image/case_42/ (stored 0%)
#   adding: content/benchmark_image/case_42/Fig. 42.1.jpg (deflated 1%)
#   adding: content/benchmark_image/case_43/ (stored 0%)
#   adding: content/benchmark_image/case_43/Fig. 43.1.jpg (deflated 1%)
#   adding: content/benchmark_image/case_24/ (stored 0%)
#   adding: content/benchmark_image/case_24/Fig. 24.1.jpg (deflated 0%)
#   adding: content/benchmark_image/case_66/ (stored 0%)
#   adding: content/benchmark_image/case_66/Fig. 66.1.jpg (deflated 6%)
#   adding: content/benchmark_image/case_8/ (stored 0%)
#   adding: content/benchmark_image/case_8/Fig. 8.1.jpg (deflated 2%)
#   adding: content/benchmark_image/case_11/ (stored 0%)
#   adding: content/benchmark_image/case_11/Fig. 11.1.jpg (deflated 1%)
#   adding: content/benchmark_image/case_48/ (stored 0%)
#   adding: content/benchmark_image/case_48/Fig. 48.1.jpg (deflated 2%)
#   adding: content/benchmark_image/case_89/ (stored 0%)
#   adding: content/benchmark_image/case_89/Fig. 89.1.jpg (deflated 2%)
#   adding: content/benchmark_image/case_15/ (stored 0%)
#   adding: content/benchmark_image/case_15/Fig. 15.1.jpg (deflated 1%)
#   adding: content/benchmark_image/case_90/ (stored 0%)
#   adding: content/benchmark_image/case_90/Fig. 90.1.jpg (deflated 2%)
#   adding: content/benchmark_image/case_47/ (stored 0%)
#   adding: content/benchmark_image/case_47/Fig. 47.2.jpg (deflated 1%)
#   adding: content/benchmark_image/case_93/ (stored 0%)
#   adding: content/benchmark_image/case_93/Fig. 93.1.jpg (deflated 2%)
#   adding: content/benchmark_image/case_78/ (stored 0%)
#   adding: content/benchmark_image/case_78/Fig. 78.1.jpg (deflated 2%)
#   adding: content/benchmark_image/case_33/ (stored 0%)
#   adding: content/benchmark_image/case_33/Fig. 33.1.jpg (deflated 4%)
#   adding: content/benchmark_image/case_1/ (stored 0%)
#   adding: content/benchmark_image/case_1/Fig. 1.2.jpg (deflated 1%)
#   adding: content/benchmark_image/case_1/Fig. 1.1.jpg (deflated 2%)
#   adding: content/benchmark_image/case_21/ (stored 0%)
#   adding: content/benchmark_image/case_21/Fig. 21.1.jpg (deflated 1%)
#   adding: content/benchmark_image/case_54/ (stored 0%)
#   adding: content/benchmark_image/case_54/Fig. 54.1.jpg (deflated 3%)
#   adding: content/benchmark_image/case_2/ (stored 0%)
#   adding: content/benchmark_image/case_2/Fig. 2.1.jpg (deflated 2%)
#   adding: content/benchmark_image/case_30/ (stored 0%)
#   adding: content/benchmark_image/case_30/Fig. 30.2.jpg (deflated 0%)
#   adding: content/benchmark_image/case_30/Fig. 30.1.jpg (deflated 0%)
#   adding: content/benchmark_image/case_85/ (stored 0%)
#   adding: content/benchmark_image/case_85/Fig. 85.1.jpg (deflated 1%)
#   adding: content/benchmark_image/case_85/Fig. 85.2.jpg (deflated 1%)
#   adding: content/benchmark_image/case_80/ (stored 0%)
#   adding: content/benchmark_image/case_80/Fig. 80.1.jpg (deflated 10%)
#   adding: content/benchmark_image/case_72/ (stored 0%)
#   adding: content/benchmark_image/case_72/Fig. 72.2.jpg (deflated 0%)
#   adding: content/benchmark_image/case_72/Fig. 72.1.jpg (deflated 1%)
#   adding: content/benchmark_image/case_35/ (stored 0%)
#   adding: content/benchmark_image/case_35/Fig. 35.1.jpg (deflated 1%)
#   adding: content/benchmark_image/case_27/ (stored 0%)
#   adding: content/benchmark_image/case_27/Fig. 27.1.jpg (deflated 2%)
#   adding: content/benchmark_image/case_94/ (stored 0%)
#   adding: content/benchmark_image/case_94/Fig. 94.1.jpg (deflated 1%)
#   adding: content/benchmark_image/case_77/ (stored 0%)
#   adding: content/benchmark_image/case_77/Fig. 77.1.jpg (deflated 2%)
#   adding: content/benchmark_image/case_83/ (stored 0%)
#   adding: content/benchmark_image/case_83/Fig. 83.1.jpg (deflated 1%)
#   adding: content/benchmark_image/case_32/ (stored 0%)
#   adding: content/benchmark_image/case_32/Fig. 32.1.jpg (deflated 2%)
#   adding: content/benchmark_image/case_81/ (stored 0%)
#   adding: content/benchmark_image/case_81/Fig. 81.1.jpg (deflated 6%)
#   adding: content/benchmark_image/case_79/ (stored 0%)
#   adding: content/benchmark_image/case_79/Fig. 79.1.jpg (deflated 0%)
#   adding: content/benchmark_image/case_6/ (stored 0%)
#   adding: content/benchmark_image/case_6/Fig. 6.1.jpg (deflated 3%)
#   adding: content/benchmark_image/case_71/ (stored 0%)
#   adding: content/benchmark_image/case_71/Fig. 71.1.jpg (deflated 12%)
#   adding: content/benchmark_image/case_62/ (stored 0%)
#   adding: content/benchmark_image/case_62/Fig. 62.2.jpg (deflated 2%)
#   adding: content/benchmark_image/case_62/Fig. 62.1.jpg (deflated 1%)
#   adding: content/benchmark_image/case_3/ (stored 0%)
#   adding: content/benchmark_image/case_3/Fig. 3.1.jpg (deflated 1%)
#   adding: content/benchmark_image/case_25/ (stored 0%)
#   adding: content/benchmark_image/case_25/Fig. 25.1.jpg (deflated 1%)
#   adding: content/benchmark_image/case_37/ (stored 0%)
#   adding: content/benchmark_image/case_37/Fig. 37.1.jpg (deflated 1%)
#   adding: content/benchmark_image/case_37/Fig. 37.2.jpg (deflated 1%)
#   adding: content/benchmark_image/case_82/ (stored 0%)
#   adding: content/benchmark_image/case_82/Fig. 82.2.jpg (deflated 2%)
#   adding: content/benchmark_image/case_82/Fig. 82.1.jpg (deflated 4%)

# %%
from google.colab import files
files.download('/content/benchmark_image.zip')

# %% [markdown]
# # Inspection

# %%
import json

with open('/content/google_gemma-3-4b-it-finetuned_generated_cases_rag.json', 'r') as f:
    data = json.load(f)

print(f"The length of the JSON file is: {len(data)}")
# Out:
# The length of the JSON file is: 3

# %%
if 'test_cases' in data:
    test_cases_field = data['test_cases']
    print(f"Type of 'test_cases': {type(test_cases_field)}")
    print(f"Length of 'test_cases': {len(test_cases_field)}")
else:
    print("'test_cases' field not found in the JSON data.")
# Out:
# Type of 'test_cases': <class 'list'>
# Length of 'test_cases': 78
